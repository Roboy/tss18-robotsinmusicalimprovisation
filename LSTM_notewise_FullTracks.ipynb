# %%
import matplotlib
matplotlib.use('Agg')
import numpy as np
import glob
import pypianoroll as ppr
import time
import music21
import os
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
import torch.utils.data as data
from utils.utilsPreprocessing import *
import time
#np.set_printoptions(threshold=np.inf)
#torch.set_printoptions(threshold=50000)

# %%
###HYPERPARAMETERS######################
epochs = 500
batch_size = 7
learning_rate = 1e-3
log_interval = 1
hidden_size = 1024
num_layers = 1
num_classes = 61
validate = False #play/show a random sample after each epoch

# %% [markdown]
# # Beat resolution
# If beat resolution = 1 --> 1 tick = 1/4 note<br>
# If beat resolution = 2 --> 1 tick = 1/8 note<br>
# If beat resolution = 4 --> 1 tick = 1/16 note<br>
# If beat resolution = 8 --> 1 tick = 1/32 note<br>
# ...

# %%
beat_resolution = 4

# %%
pathToFiles = "/media/EXTHD/niciData/Datasets/Nottingham/"
midiDatasetTrain = createDatasetLSTM(pathToFiles + "train/*.mid", beat_res = beat_resolution,
                                    force_length=True, force_value=16)
midiDatasetTrain.setMaxLength()
##TO DO
#midiDatasetTrain.setMeanLength()

midiDatasetTest = createDatasetLSTM(pathToFiles + "test/*.mid", beat_res = beat_resolution,
                                   force_length=True, force_value=16)
midiDatasetTest.setMaxLength()

midiDatasetVal = createDatasetLSTM(pathToFiles + "valid/*.mid",
                                  force_length=True, force_value=16)
midiDatasetVal.setMaxLength()

train_loader = torch.utils.data.DataLoader(midiDatasetTrain, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader = torch.utils.data.DataLoader(midiDatasetTest, batch_size=batch_size, shuffle=False, drop_last=True)
val_loader = torch.utils.data.DataLoader(midiDatasetVal, batch_size=1, shuffle=True, drop_last=True)
# Out:
# Longest sequences contains 16 ticks
# Longest sequences contains 16 ticks
# Longest sequences contains 16 ticks

# %%
print("\nThere are {} songs in the training set\n".format(len(midiDatasetTrain)))
print("There are {} songs in the test set\n".format(len(midiDatasetTest)))
print("There are {} songs in the validation set\n".format(len(midiDatasetVal)))
# Out:
# There are 694 songs in the training set
#
# There are 170 songs in the test set
#
# There are 173 songs in the validation set

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class LSTM_notewise(nn.Module):
    def __init__(self, hidden_size=400, num_layers=2, batch_size=1):
        super(LSTM_notewise, self).__init__()
        
        self.input_size = 61
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.batch_size = batch_size
        self.num_classes = 61

        
        self.i2h = nn.Linear(self.input_size, self.hidden_size)
        #self.batch_norm = nn.BatchNorm1d(self.hidden_size)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size,
                            self.num_layers, batch_first=True,
                            dropout=0)
        self.h2o = nn.Linear(self.hidden_size, self.num_classes)
        
    def initState(self):
        state = torch.zeros(self.num_layers,
                            self.batch_size, 
                            self.hidden_size).double().to(device)
        return state
    
    def forward(self, input, seq_lengths):
        h_t = self.initState()
        c_t = self.initState()
        
        embedded_notes = self.i2h(input)
        #embedded_notes = self.batch_norm(embedded_notes)
        embedded_notes = torch.nn.utils.rnn.pack_padded_sequence(embedded_notes, 
                                                                 seq_lengths, 
                                                                 batch_first=True)    
        out, (h_t, c_t) = self.lstm(embedded_notes, (h_t, c_t))
        out, out_lengths = torch.nn.utils.rnn.pad_packed_sequence(out, batch_first=True)
        out = self.h2o(out)
        neg_out = (1-out)
        
        #print('out', out)
        #print('neg_out', neg_out)
        out = torch.stack((out, neg_out), dim=3)
        out = out.view(-1, 2)

        
        return out

# %%
model = LSTM_notewise(hidden_size=hidden_size, num_layers=num_layers, 
                      batch_size=batch_size).double().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

#initialize lstm weights
from torch.nn import init
init_range = 1.
for layer_p in model.lstm._all_weights:
    for p in layer_p:
        if 'weight' in p:
            init.xavier_uniform_(model.lstm.__getattr__(p), gain=10)

# %%
#load model
#from loadModel import loadStateDict
#pathToModel = "../models/LSTM_notewise.pth"

#model = loadStateDict(model, pathToModel)

# %%
def train(epoch):
    
    model.train()
    train_loss = 0
    criterion = nn.CrossEntropyLoss()
    for batch_idx, data in enumerate(train_loader):
        optimizer.zero_grad()
        input_lstm, ground_truth, seq_lengths = reorderBatch(data)
        prediction = model(input_lstm.double().to(device), seq_lengths)
        ground_truth = ground_truth.to(device)
        
        #print('inptu_lstm: ', input_lstm.size())
        #print("prediction: ",prediction.size(),"ground_truths: ", ground_truth.size())
        #print('prediction', torch.argmax(prediction[0,:,:]))
        #print('ground_truth', torch.argmax(ground_truth[0,:,:]))
        
        loss = criterion(prediction, ground_truth.contiguous().view(-1).long())
        loss.backward()
        
        print("lstm gradients: ", model.lstm.weight_ih_l0.grad)

        train_loss += loss.item()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        #reshape
        prediction = prediction.view(model.batch_size,-1, num_classes, 2)
        #delete negative outputs
        prediction = prediction[:,:,:,0] 
        print("prediction: ",prediction.size(),"ground_truth: ", ground_truth.size())
        if(batch_idx % log_interval == 0):
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * input_lstm.size(0), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.item() / input_lstm.size(0)))
            print('ground_truth', torch.argmax(ground_truth[0], dim=1))
            print('prediction', torch.argmax(prediction[0], dim=1))
            
    print('====> Epoch: {} Average Loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))
        
    return train_loss / len(train_loader.dataset)

def test(epoch):
    model.eval()
    test_loss = 0
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        for i, data in enumerate(test_loader):
            input_lstm, ground_truth, seq_lengths = reorderBatch(data)
            prediction = model(input_lstm.double().to(device), seq_lengths)
            test_loss += criterion(prediction, ground_truth.view(-1).long().to(device)).item()
            prediction = prediction.view(model.batch_size,-1,num_classes)
            if(False):#i % log_interval == 0):
                print('prediction', torch.argmax(prediction,dim=2))
                print('ground_truth', torch.argmax(ground_truth,dim=2))
    
    print('====> Test set Loss: {:.4f}'.format(test_loss/len(test_loader.dataset)))
    return test_loss/len(test_loader.dataset)

def val(epoch):
    model.eval()
    val_loss = 0
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            input_lstm, ground_truth, seq_lengths = reorderBatch(data)
            prediction = model(input_lstm.double().to(device), seq_lengths)
            val_loss += criterion(prediction, ground_truth.to(device)).item()
            
            break
    print('====> Validation Loss: {:.4f}'.format(val_loss))
    return val_loss

# %%
import matplotlib.pyplot as plt


train_losses = []
test_losses = []
if validate:
    val_losses = []
best_test_loss = 999
for epoch in range(1, epochs + 1):
    #train
    current_train_loss = (train(epoch))
    train_losses.append(current_train_loss)
    #test
    current_test_loss = test(epoch)
    test_losses.append(current_test_loss)
    #save if model better than best model
    if(current_test_loss < best_test_loss):
        best_test_loss = current_test_loss
        #torch.save(model.state_dict(),'/media/EXTHD/niciData/LSTM_notewise.pth')
    
    #validate
    if validate:
        current_val_loss = val(epoch)
        val_losses.append(current_val_loss)
 
    
plt.plot(train_losses, color='red', label='Train loss')
plt.plot(test_losses, color='orange', label='Test loss')
if validate:
    plt.plot(val_losses, color='yellow', label='Validation loss')
plt.legend()
plt.savefig('LSTM_notewise_Nottingham.png')
#plt.show()
# Out:
# /home/nici/workspace/.env3/lib/python3.5/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# lstm gradients:  tensor([[ 8.0819e-05, -2.7150e-05,  4.6065e-05,  ...,  1.2552e-04,
#          -1.9836e-04,  2.9426e-05],
#         [ 8.4046e-05,  1.3505e-04,  1.1301e-04,  ...,  1.6413e-04,
#           3.5838e-05,  1.6570e-05],
#         [-8.0412e-05, -1.7736e-05, -7.4031e-05,  ...,  2.3825e-05,
#           5.1795e-05, -1.3786e-05],
#         ...,
#         [-5.3285e-05,  9.8481e-05, -2.0244e-04,  ..., -2.2879e-04,
#           2.4916e-04,  3.4715e-05],
#         [ 9.4228e-06, -3.9444e-05,  1.5473e-04,  ...,  1.3631e-04,
#          -5.8519e-05, -8.7096e-05],
#         [-8.5752e-05,  1.0426e-05,  1.7060e-05,  ..., -5.5685e-05,
#           1.4286e-04, -6.6517e-05]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [0/694 (0%)]	Loss: 0.179624
# ground_truth tensor([31, 60, 60, 38, 43, 60, 60, 35, 38, 60, 60, 60, 38, 38, 60], device='cuda:0')
# prediction tensor([16, 35, 24, 55, 55, 23, 23, 55, 23, 55, 23, 23, 16, 40, 40], device='cuda:0')
# lstm gradients:  tensor([[-8.7534e-06, -2.8826e-05,  1.2230e-04,  ..., -6.1765e-05,
#          -8.2664e-06, -9.1468e-06],
#         [ 8.3740e-05, -2.1397e-04,  4.7215e-04,  ...,  4.1595e-04,
#          -5.6070e-05, -3.1242e-04],
#         [-5.1425e-05, -1.1350e-04, -1.9563e-04,  ...,  9.2806e-07,
#           4.0796e-05,  8.6669e-05],
#         ...,
#         [-5.1987e-05,  3.9398e-05,  5.9029e-05,  ..., -7.4942e-05,
#           5.7267e-05,  4.6587e-06],
#         [ 1.5559e-04,  3.3838e-06, -1.3305e-04,  ...,  1.5444e-04,
#           6.7181e-05,  8.0955e-05],
#         [-1.3783e-04,  7.8037e-05, -2.8877e-04,  ..., -4.0509e-04,
#           2.2348e-04,  7.1029e-05]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [7/694 (1%)]	Loss: 0.156036
# ground_truth tensor([33, 33, 60, 26, 26, 26, 60, 30, 30, 30, 60, 33, 33, 33, 60], device='cuda:0')
# prediction tensor([11,  4,  4, 35, 25, 25, 23, 23, 26, 26, 29, 38, 16, 26, 26], device='cuda:0')
# lstm gradients:  tensor([[-1.8121e-07,  5.8638e-06,  2.8524e-05,  ...,  2.5281e-05,
#          -1.5237e-07, -1.0172e-05],
#         [ 7.2758e-05, -9.5186e-05, -3.3926e-06,  ..., -5.7796e-06,
#          -7.8663e-06, -2.4718e-05],
#         [ 3.5840e-05, -3.8578e-05,  1.1990e-04,  ...,  1.4639e-04,
#          -1.9885e-04,  4.6229e-05],
#         ...,
#         [ 6.5614e-05, -1.8349e-05, -4.9637e-05,  ...,  2.8495e-05,
#           9.8306e-05,  4.7323e-06],
#         [ 9.3402e-05,  3.6373e-05, -7.6491e-05,  ...,  1.0607e-04,
#           1.9817e-04,  3.5533e-05],
#         [-8.0852e-05,  1.0757e-05, -2.8502e-04,  ..., -3.1228e-04,
#           3.0593e-04,  6.1637e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [14/694 (2%)]	Loss: 0.125971
# ground_truth tensor([40, 40, 60, 41, 41, 41, 60, 42, 42, 42, 60, 43, 60, 45, 60], device='cuda:0')
# prediction tensor([11, 35, 48, 54, 54,  8, 54, 31, 31, 26,  4, 34, 34, 29, 29], device='cuda:0')
# lstm gradients:  tensor([[-4.5136e-05,  3.3009e-05, -5.2789e-05,  ..., -1.1309e-04,
#           1.1384e-04, -2.4405e-05],
#         [ 2.8029e-05, -2.3910e-05,  7.5949e-05,  ...,  8.3696e-05,
#          -1.4385e-04,  2.8766e-05],
#         [ 3.3189e-05,  1.4182e-04,  3.2697e-05,  ..., -1.0771e-04,
#          -1.4485e-04,  9.4480e-05],
#         ...,
#         [ 2.5829e-04, -1.2326e-04,  2.2559e-04,  ...,  3.6647e-04,
#          -3.1226e-04,  1.2737e-04],
#         [-5.0015e-05,  4.2912e-05,  1.4209e-06,  ...,  7.2627e-07,
#          -1.0524e-05, -3.3998e-05],
#         [ 4.3794e-05, -7.1604e-05,  1.5724e-04,  ...,  2.6467e-04,
#           2.5253e-05, -1.5711e-04]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [21/694 (3%)]	Loss: 0.099527
# ground_truth tensor([42, 42, 60, 43, 43, 43, 43, 43, 60, 45, 60, 43, 43, 43, 60], device='cuda:0')
# prediction tensor([11, 17, 48,  4, 32, 54, 56, 23, 56, 56, 18, 18, 18, 23, 33], device='cuda:0')
# lstm gradients:  tensor([[ 8.5304e-06, -3.0240e-06,  7.9872e-06,  ...,  1.0750e-05,
#           3.7032e-06, -1.6336e-06],
#         [-5.8886e-05, -5.8823e-06,  4.5493e-05,  ..., -1.1265e-04,
#          -2.5167e-05, -1.0774e-05],
#         [-1.6384e-05,  4.1008e-05, -1.0365e-04,  ..., -1.0204e-04,
#           1.7477e-04,  4.3964e-05],
#         ...,
#         [-2.7839e-05,  2.4413e-06, -3.8675e-05,  ..., -8.1791e-05,
#           7.4145e-05, -5.2403e-07],
#         [ 2.4588e-05,  5.0726e-06,  8.9171e-06,  ...,  1.5125e-05,
#          -2.0378e-05,  2.5525e-05],
#         [ 4.3205e-05,  1.4889e-05,  4.5676e-05,  ...,  9.0509e-05,
#          -6.6933e-05,  4.7998e-05]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [28/694 (4%)]	Loss: 0.066692
# ground_truth tensor([40, 60, 60, 37, 40, 60, 60, 33, 33, 60, 60, 35, 38, 60, 60], device='cuda:0')
# prediction tensor([11, 21, 48, 16, 16, 29, 29, 16,  4, 18,  4,  4,  4, 29, 29], device='cuda:0')
# lstm gradients:  tensor([[ 8.7701e-06,  9.1643e-06, -1.0693e-05,  ..., -7.4271e-06,
#           1.0980e-05,  2.4441e-08],
#         [-5.8494e-05,  7.2622e-05, -1.2723e-04,  ..., -1.5383e-04,
#           1.0276e-04,  5.6231e-05],
#         [ 3.7121e-06,  2.2278e-05,  2.4249e-06,  ..., -5.6135e-06,
#           4.1098e-05, -2.4371e-06],
#         ...,
#         [-3.4065e-05,  5.4255e-06, -2.3111e-05,  ..., -3.6075e-05,
#           2.6963e-05,  4.2088e-06],
#         [ 5.2763e-06, -7.0682e-06,  3.1200e-05,  ...,  1.9931e-05,
#          -3.5720e-05, -1.3382e-05],
#         [-4.0321e-05, -1.2499e-05,  4.3129e-05,  ...,  1.0650e-05,
#          -2.4956e-05, -1.1248e-05]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [35/694 (5%)]	Loss: 0.046108
# ground_truth tensor([40, 60, 60, 37, 40, 60, 60, 33, 33, 60, 60, 35, 38, 60, 60], device='cuda:0')
# prediction tensor([11, 21, 48, 16, 16, 29, 29, 29, 29, 29, 18, 27, 18, 29, 35], device='cuda:0')
# lstm gradients:  tensor([[ 1.0832e-06, -9.8601e-07,  3.4266e-06,  ...,  5.7279e-06,
#          -5.1663e-06, -2.2444e-07],
#         [-3.1125e-05,  2.2492e-05, -6.6974e-05,  ..., -6.2366e-05,
#           7.7454e-05,  1.2413e-05],
#         [-2.5894e-05,  1.3896e-05, -5.9955e-05,  ..., -5.9931e-05,
#           5.7194e-05,  1.6545e-05],
#         ...,
#         [-1.6097e-05,  1.0596e-05, -3.9776e-05,  ..., -4.5931e-05,
#           3.6705e-05,  6.7231e-06],
#         [ 3.4434e-06, -4.0678e-06, -3.7010e-07,  ..., -6.7987e-07,
#          -8.9981e-06,  3.0910e-06],
#         [ 5.8084e-06,  4.9507e-07, -7.7480e-06,  ...,  1.3959e-05,
#          -2.4153e-06,  4.0937e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [42/694 (6%)]	Loss: 0.029771
# ground_truth tensor([60, 32, 60, 33, 33, 33, 60, 33, 60, 35, 60, 33, 33, 33, 60], device='cuda:0')
# prediction tensor([11, 48, 48,  4,  4,  4,  4,  4, 18, 21, 21, 18, 21, 21, 21], device='cuda:0')
# lstm gradients:  tensor([[ 4.4357e-07, -1.5622e-06,  3.7053e-06,  ...,  3.4925e-06,
#          -5.9864e-06,  9.8849e-08],
#         [-9.7063e-07,  1.4820e-05, -2.1868e-05,  ..., -2.2104e-05,
#           3.5149e-05,  5.7487e-06],
#         [-9.4245e-06,  9.4929e-06, -2.8060e-05,  ..., -3.2859e-05,
#           2.6750e-05,  7.5087e-06],
#         ...,
#         [-7.0422e-06,  1.9424e-06, -1.0821e-05,  ..., -1.4636e-05,
#           9.5953e-06, -1.6526e-06],
#         [-4.6834e-07, -3.9364e-06,  7.1079e-06,  ...,  3.7866e-06,
#          -1.0037e-05, -7.6231e-07],
#         [-5.4886e-07,  1.1655e-06, -4.5331e-06,  ..., -8.8357e-07,
#           7.9982e-08,  4.6341e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [49/694 (7%)]	Loss: 0.021967
# ground_truth tensor([22, 60, 60, 29, 34, 60, 60, 60, 34, 60, 60, 34, 29, 29, 60], device='cuda:0')
# prediction tensor([ 4, 11, 48, 11, 11, 16, 16, 16, 16, 21, 47, 16, 18, 18, 18], device='cuda:0')
# lstm gradients:  tensor([[-2.2593e-07, -7.2515e-07,  1.1152e-07,  ..., -3.4186e-07,
#          -4.6414e-07, -4.1485e-08],
#         [-8.4979e-06,  7.8426e-06, -1.1750e-05,  ..., -6.0078e-06,
#           1.5197e-05, -7.4888e-07],
#         [-1.4982e-05,  5.7116e-06, -1.5697e-05,  ..., -1.5709e-05,
#           1.6630e-05,  8.7767e-06],
#         ...,
#         [-7.1109e-06,  5.9258e-06, -9.5143e-06,  ..., -8.0779e-06,
#           1.1969e-05,  1.8389e-06],
#         [ 1.6451e-06, -1.8921e-06, -2.4814e-07,  ...,  2.7746e-07,
#          -3.6280e-07, -2.2304e-06],
#         [-5.9712e-06,  9.4601e-06, -6.0254e-06,  ..., -5.8996e-06,
#           7.7511e-06,  5.8582e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [56/694 (8%)]	Loss: 0.018857
# ground_truth tensor([30, 60, 60, 30, 31, 60, 60, 31, 35, 60, 60, 30, 33, 33, 60], device='cuda:0')
# prediction tensor([17, 48, 48, 48, 54, 21, 18, 18, 21, 18, 16, 16, 16, 18, 18], device='cuda:0')
# lstm gradients:  tensor([[ 1.4996e-07, -1.3965e-06,  3.4916e-06,  ...,  2.2552e-06,
#          -2.9891e-06, -6.6181e-07],
#         [ 2.2505e-07,  2.9172e-06, -8.6344e-06,  ..., -2.2396e-06,
#           3.5919e-06,  3.3619e-06],
#         [-3.7569e-06,  6.3402e-06, -1.1102e-05,  ..., -7.4327e-06,
#           1.2302e-05,  3.3517e-06],
#         ...,
#         [-5.2125e-06,  4.3355e-06, -8.6603e-06,  ..., -8.5875e-06,
#           9.8577e-06,  1.6714e-06],
#         [ 6.5089e-07,  3.4159e-07, -9.3090e-07,  ..., -3.1837e-07,
#           4.6568e-07,  4.8992e-07],
#         [-3.4370e-06,  5.2622e-06, -1.1526e-05,  ..., -8.0898e-06,
#           1.2374e-05,  2.3565e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [63/694 (9%)]	Loss: 0.015303
# ground_truth tensor([60, 38, 60, 40, 60, 37, 60, 37, 60, 37, 60, 40, 60, 45, 60], device='cuda:0')
# prediction tensor([ 4, 16, 48, 12, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21], device='cuda:0')
# lstm gradients:  tensor([[ 3.9123e-07, -1.7047e-06,  1.6164e-06,  ...,  5.8197e-07,
#          -2.2746e-06,  1.0797e-07],
#         [-4.7490e-06,  6.7280e-06, -2.3730e-06,  ..., -2.5603e-06,
#           8.1819e-06, -1.1116e-06],
#         [-7.1696e-06, -2.3546e-06, -1.0719e-05,  ..., -9.4640e-06,
#           7.6076e-06,  2.6490e-06],
#         ...,
#         [-2.2609e-06,  1.5030e-06, -4.9950e-06,  ..., -6.7135e-06,
#           4.1072e-06,  2.1926e-06],
#         [-2.1208e-07, -1.0527e-07,  4.7642e-08,  ..., -4.0741e-07,
#           2.8511e-07, -1.0502e-07],
#         [-1.9082e-06,  1.2174e-06, -2.4236e-06,  ..., -4.3674e-06,
#           3.9649e-06,  4.5412e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [70/694 (10%)]	Loss: 0.014770
# ground_truth tensor([33, 60, 60, 60, 26, 60, 60, 33, 38, 60, 60, 38, 37, 60, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 16, 21, 21, 16, 21, 21, 21, 16, 21, 16, 21], device='cuda:0')
# lstm gradients:  tensor([[ 7.9591e-07, -7.4861e-07,  1.1731e-06,  ...,  2.3187e-06,
#          -2.1903e-06, -1.9167e-07],
#         [-1.3684e-06,  3.7901e-07, -1.0312e-06,  ..., -9.6405e-07,
#           1.7185e-06,  2.1779e-07],
#         [-7.3301e-06, -9.5363e-07, -9.8546e-06,  ..., -9.4983e-06,
#           7.4896e-06,  4.2875e-06],
#         ...,
#         [-2.0429e-06,  1.6176e-06, -4.0060e-06,  ..., -4.9312e-06,
#           3.3993e-06,  2.6592e-06],
#         [-5.5104e-07,  3.2674e-07, -1.5234e-07,  ..., -4.3004e-07,
#           7.6579e-07,  1.7442e-07],
#         [ 1.2034e-06,  4.3286e-07, -1.1399e-06,  ...,  1.5002e-06,
#          -8.9365e-07,  1.4762e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [77/694 (11%)]	Loss: 0.013324
# ground_truth tensor([60, 60, 33, 33, 26, 60, 60, 31, 30, 60, 60, 26, 25, 60, 26], device='cuda:0')
# prediction tensor([17, 48, 16, 48, 16, 16, 16, 16, 21, 21, 16, 16, 21, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 1.2885e-07, -3.0013e-07,  1.3803e-06,  ...,  1.0925e-06,
#          -3.4272e-07, -7.0392e-07],
#         [-1.2480e-07,  4.8163e-07, -2.2558e-06,  ..., -1.3743e-06,
#           2.6457e-06,  6.6275e-07],
#         [-7.2256e-06, -9.3963e-07, -1.8161e-05,  ..., -1.4995e-05,
#           6.9407e-06,  7.8747e-06],
#         ...,
#         [-6.0530e-07,  6.6524e-07, -4.3442e-06,  ..., -4.5181e-06,
#          -5.3922e-07,  2.7449e-06],
#         [ 1.1405e-07, -1.1059e-07,  2.7215e-07,  ...,  3.9763e-07,
#          -2.9402e-07, -3.6321e-08],
#         [ 1.1170e-06, -5.2482e-07,  3.1472e-06,  ...,  1.5238e-06,
#          -1.4794e-06, -2.1600e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [84/694 (12%)]	Loss: 0.014859
# ground_truth tensor([26, 26, 60, 31, 31, 31, 31, 31, 60, 35, 60, 33, 60, 30, 60], device='cuda:0')
# prediction tensor([11, 48, 48, 48, 23, 21, 21, 21, 21, 21, 21, 21, 21, 16, 21], device='cuda:0')
# lstm gradients:  tensor([[ 2.2595e-07, -8.6283e-07,  6.4114e-07,  ...,  1.4258e-06,
#          -1.4705e-06,  3.8557e-08],
#         [-2.0268e-06, -8.5968e-08, -2.0132e-06,  ..., -3.1211e-07,
#           9.8050e-07,  2.5109e-07],
#         [-3.9658e-06, -7.5760e-07, -6.2831e-06,  ..., -5.5667e-06,
#           6.0178e-06,  6.8120e-07],
#         ...,
#         [-3.7618e-07,  5.1948e-07, -1.6693e-06,  ...,  8.0601e-08,
#           7.7155e-07,  2.3209e-07],
#         [-1.9811e-07,  4.9750e-08, -1.9063e-07,  ..., -1.1220e-07,
#           5.9102e-07, -1.7488e-07],
#         [ 1.1051e-06, -5.1592e-07,  8.4234e-07,  ...,  2.2204e-06,
#          -2.2289e-06,  8.0582e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [91/694 (13%)]	Loss: 0.011950
# ground_truth tensor([60, 33, 60, 31, 60, 30, 60, 31, 60, 33, 60, 35, 35, 35, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 21, 21, 21, 16, 21, 16, 16, 16, 21, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-6.9468e-07, -9.8102e-07,  7.8813e-07,  ..., -7.7955e-07,
#           3.8672e-07, -8.7170e-07],
#         [ 1.4436e-07,  3.5832e-07,  3.1249e-06,  ..., -5.7704e-07,
#          -3.2431e-06,  1.3560e-06],
#         [-2.3892e-06,  6.7722e-07, -4.3330e-06,  ..., -4.8183e-06,
#           6.0127e-06,  7.2743e-07],
#         ...,
#         [-1.6503e-06, -5.0968e-07,  5.1877e-07,  ..., -1.4701e-06,
#           9.2760e-07, -6.1276e-07],
#         [-5.0098e-07,  5.4338e-07, -8.8291e-07,  ..., -6.7754e-07,
#           9.7019e-07,  2.3331e-07],
#         [-1.2956e-06, -1.7927e-07,  5.7485e-07,  ..., -4.8771e-07,
#          -1.3686e-06, -1.6681e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [98/694 (14%)]	Loss: 0.012302
# ground_truth tensor([60, 60, 60, 40, 38, 60, 60, 33, 31, 60, 60, 30, 31, 31, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 21, 21, 21, 21, 21, 21, 16, 16, 16, 21, 21], device='cuda:0')
# lstm gradients:  tensor([[-2.4148e-07, -3.4744e-07,  3.2480e-07,  ..., -9.6183e-08,
#           9.9409e-07, -5.9002e-07],
#         [ 3.3735e-06,  4.6039e-06,  8.3822e-07,  ..., -2.0087e-07,
#           5.5766e-07,  2.3364e-07],
#         [-6.5949e-06, -1.2664e-06, -9.4082e-06,  ..., -9.8570e-06,
#           5.4913e-06,  4.0348e-06],
#         ...,
#         [-1.3842e-06, -1.4940e-07, -1.3911e-06,  ..., -3.1015e-06,
#           9.6392e-07,  9.8330e-07],
#         [ 3.3150e-07,  1.0263e-06, -7.4301e-07,  ..., -3.7563e-07,
#           9.4945e-07,  3.3237e-07],
#         [ 5.1062e-07, -3.5815e-07,  3.6038e-07,  ...,  6.2824e-07,
#          -1.4822e-06,  2.7310e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [105/694 (15%)]	Loss: 0.011961
# ground_truth tensor([34, 34, 60, 36, 36, 36, 60, 38, 38, 38, 38, 38, 60, 36, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 48, 48, 21, 21, 21, 21, 21, 21, 21, 21, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-6.7556e-07, -1.3368e-06,  9.2319e-07,  ...,  5.0515e-07,
#          -1.6216e-06, -8.6388e-07],
#         [ 2.0646e-06, -2.6305e-06,  4.9280e-06,  ...,  5.6486e-06,
#          -8.2741e-06, -6.5056e-07],
#         [ 7.4188e-07,  6.8208e-07, -2.0165e-06,  ..., -6.6511e-07,
#           2.8531e-06,  1.0104e-06],
#         ...,
#         [-1.4915e-06, -2.8555e-07,  4.5753e-07,  ..., -1.1368e-06,
#          -3.2869e-07, -3.9549e-07],
#         [-5.1365e-07,  9.8750e-08, -3.8567e-07,  ..., -5.0573e-07,
#           7.1899e-07, -1.0862e-07],
#         [-2.7142e-07,  4.0902e-07,  1.8580e-06,  ...,  7.8634e-07,
#          -9.3132e-07, -1.9753e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [112/694 (16%)]	Loss: 0.010498
# ground_truth tensor([60, 33, 60, 31, 31, 31, 31, 31, 60, 35, 60, 38, 38, 38, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 21, 21, 21, 21, 21, 16, 21, 16, 21, 16, 21], device='cuda:0')
# lstm gradients:  tensor([[-6.7361e-07, -7.0421e-07,  5.5689e-08,  ..., -9.2382e-07,
#           8.0156e-07, -4.5113e-07],
#         [ 8.6473e-07,  2.2937e-06,  1.0898e-06,  ...,  5.0825e-07,
#          -5.2434e-07,  8.7260e-07],
#         [-5.7294e-06, -9.4815e-07, -5.5278e-06,  ..., -5.3456e-06,
#           4.2578e-06,  2.2986e-06],
#         ...,
#         [-7.3985e-07,  1.9171e-07, -3.3508e-07,  ..., -1.5368e-06,
#           5.0888e-07,  5.3073e-07],
#         [-7.4849e-07,  3.1426e-07, -4.7880e-07,  ..., -8.5238e-07,
#           7.3525e-07,  3.7236e-07],
#         [-1.6898e-07,  6.7156e-07, -8.4743e-07,  ..., -6.1590e-07,
#           2.1527e-07,  1.1216e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [119/694 (17%)]	Loss: 0.010793
# ground_truth tensor([33, 33, 60, 38, 38, 38, 60, 33, 60, 31, 60, 30, 60, 26, 60], device='cuda:0')
# prediction tensor([48, 48, 48, 12, 21, 21, 21, 16, 16, 16, 21, 16, 16, 16, 21], device='cuda:0')
# lstm gradients:  tensor([[-2.9033e-07, -2.7872e-07,  1.1832e-06,  ..., -8.4875e-07,
#          -2.0485e-07, -2.2420e-07],
#         [-1.1437e-06, -8.6852e-07,  3.8698e-06,  ..., -4.6036e-06,
#           5.0228e-07, -3.2851e-07],
#         [-4.0291e-07,  1.8707e-06, -7.1117e-06,  ..., -2.0951e-07,
#           4.6340e-06,  5.6527e-07],
#         ...,
#         [-5.6097e-07,  4.4122e-07, -8.3879e-07,  ..., -4.9791e-07,
#           2.1567e-07, -4.1547e-07],
#         [-6.7563e-07,  4.2471e-07, -1.4767e-06,  ..., -1.2663e-06,
#           1.6413e-06, -1.2978e-07],
#         [-1.5691e-06,  8.6187e-07, -1.4228e-06,  ..., -3.2209e-06,
#           1.5080e-06,  6.0484e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [126/694 (18%)]	Loss: 0.009731
# ground_truth tensor([30, 60, 60, 33, 33, 33, 60, 33, 33, 33, 60, 35, 35, 35, 60], device='cuda:0')
# prediction tensor([11, 48, 55, 48, 16, 16, 16, 16, 16, 16, 16, 16, 12, 12, 12], device='cuda:0')
# lstm gradients:  tensor([[-7.7941e-09, -6.5592e-07,  1.0756e-06,  ...,  5.0589e-07,
#          -3.9785e-07, -4.8637e-07],
#         [-4.5478e-06,  1.5735e-06, -5.8650e-06,  ..., -9.8997e-06,
#           8.2005e-06,  7.0196e-07],
#         [ 1.0146e-07,  5.3100e-07, -1.7656e-06,  ..., -9.6789e-07,
#           1.8574e-06,  6.9628e-07],
#         ...,
#         [-2.1352e-06,  2.2561e-07, -2.0867e-06,  ..., -4.9417e-06,
#           2.9154e-06,  3.7844e-07],
#         [-2.2856e-07,  4.6612e-07, -1.2151e-06,  ..., -1.0360e-06,
#           1.6808e-06,  3.0589e-07],
#         [ 1.1561e-06, -1.3371e-06,  1.2959e-06,  ...,  2.3120e-06,
#          -3.6847e-06, -4.5244e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [133/694 (19%)]	Loss: 0.009931
# ground_truth tensor([38, 60, 60, 35, 38, 60, 60, 31, 35, 60, 60, 26, 31, 60, 60], device='cuda:0')
# prediction tensor([11, 48, 55, 12, 21, 21, 16, 16, 21, 21, 16, 16, 21, 21, 16], device='cuda:0')
# lstm gradients:  tensor([[-2.4586e-07, -8.4294e-08,  9.1515e-07,  ..., -2.1931e-07,
#          -6.0649e-07, -1.5005e-07],
#         [-3.1400e-06,  1.2986e-06,  8.7187e-07,  ..., -1.8193e-06,
#           3.4273e-06, -1.2875e-06],
#         [-1.7524e-08,  5.7108e-07, -3.6643e-06,  ..., -1.4457e-06,
#           2.6396e-06,  9.4960e-07],
#         ...,
#         [-3.8429e-07,  3.4390e-07, -2.8305e-07,  ..., -9.3757e-07,
#          -9.2990e-07,  4.2536e-07],
#         [-2.0343e-07,  4.9278e-07, -6.0369e-07,  ..., -2.1537e-07,
#           9.8148e-07,  6.9104e-08],
#         [ 1.0272e-06, -1.0531e-06,  1.8680e-06,  ...,  2.5294e-06,
#          -3.4967e-06, -8.4689e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [140/694 (20%)]	Loss: 0.010458
# ground_truth tensor([31, 31, 60, 36, 36, 36, 60, 40, 40, 60, 60, 36, 36, 36, 60], device='cuda:0')
# prediction tensor([54, 54, 48, 54, 16, 21, 21, 21, 21, 21, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-7.7678e-07, -7.8257e-07,  9.0762e-07,  ..., -1.3829e-06,
#          -8.9694e-08, -3.4017e-07],
#         [ 9.2477e-08, -3.9397e-07,  1.4650e-06,  ...,  9.1842e-07,
#          -2.0722e-06,  1.8241e-07],
#         [ 2.4671e-08,  3.9549e-07, -1.5344e-06,  ..., -3.5584e-07,
#           1.5233e-06,  3.2380e-07],
#         ...,
#         [ 1.8161e-07,  2.5407e-07,  9.5622e-07,  ...,  1.3232e-06,
#          -8.3889e-07, -2.0086e-07],
#         [-4.3600e-08,  2.7250e-07, -6.1881e-07,  ..., -3.2308e-07,
#           9.4695e-07,  1.9722e-07],
#         [ 1.3999e-06,  2.6481e-07,  1.3515e-06,  ...,  1.2971e-06,
#          -1.6868e-06, -4.4882e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [147/694 (21%)]	Loss: 0.010804
# ground_truth tensor([33, 33, 60, 26, 30, 60, 60, 26, 30, 30, 60, 60, 33, 33, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 12, 21, 16, 16, 21, 21, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-6.2436e-07, -4.1885e-07,  7.1811e-07,  ..., -3.2967e-07,
#          -4.4395e-07, -3.5825e-07],
#         [-4.9428e-07,  1.9756e-07, -4.0626e-06,  ..., -2.4447e-06,
#           2.2426e-06,  1.2385e-06],
#         [-1.7130e-06, -1.6189e-07, -2.3340e-06,  ..., -6.6236e-07,
#           1.9671e-06,  1.3691e-06],
#         ...,
#         [-1.1370e-06,  4.3376e-07, -4.5374e-07,  ..., -1.5273e-06,
#           9.7006e-07,  8.3337e-07],
#         [-3.1408e-07,  3.0986e-07, -8.4350e-07,  ..., -4.9471e-07,
#           9.8737e-07,  4.8960e-07],
#         [-6.0341e-07, -2.3476e-07,  5.0788e-07,  ..., -1.3103e-06,
#           3.0664e-07, -4.7075e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [154/694 (22%)]	Loss: 0.009824
# ground_truth tensor([60, 38, 60, 60, 60, 60, 60, 60, 60, 33, 60, 33, 60, 33, 60], device='cuda:0')
# prediction tensor([48, 48, 48, 55, 12, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 6.8116e-07, -9.5575e-07,  1.6043e-06,  ...,  2.1127e-06,
#          -2.6346e-06,  1.2387e-07],
#         [-2.5344e-06,  2.7816e-06, -3.8083e-06,  ..., -3.7341e-06,
#           5.3190e-06,  1.0053e-07],
#         [-2.7894e-07,  2.3588e-08, -7.4104e-07,  ..., -8.7849e-07,
#           1.6284e-07,  4.7089e-07],
#         ...,
#         [ 1.8753e-08, -4.9212e-08, -4.0393e-07,  ..., -9.2906e-07,
#           5.6836e-07,  4.7977e-07],
#         [-1.0427e-07, -5.8981e-08,  1.9472e-08,  ..., -2.6612e-07,
#           1.5121e-07, -3.4279e-08],
#         [ 1.1493e-06, -4.5031e-07,  5.5394e-07,  ...,  1.4221e-06,
#           9.2009e-08, -2.7657e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [161/694 (23%)]	Loss: 0.011171
# ground_truth tensor([28, 28, 60, 33, 28, 28, 60, 33, 28, 60, 60, 35, 37, 37, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 48, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 2.7232e-07, -1.1896e-06,  2.2132e-06,  ...,  1.5039e-06,
#          -1.4070e-06, -7.6454e-07],
#         [-3.9281e-06, -1.7525e-06, -8.9554e-07,  ..., -4.1814e-07,
#          -3.9374e-07, -1.5805e-06],
#         [-8.8621e-07,  1.4553e-07, -1.8774e-06,  ..., -1.7158e-06,
#           1.1328e-06,  6.6261e-07],
#         ...,
#         [-5.4038e-07,  3.4282e-07, -6.1075e-07,  ..., -2.1301e-07,
#           3.9468e-07,  1.0840e-07],
#         [-7.4315e-08,  7.2005e-08, -2.6489e-07,  ..., -2.3698e-07,
#           1.4070e-07,  1.5406e-07],
#         [-1.1441e-08, -1.7967e-07,  1.2829e-06,  ...,  2.9921e-07,
#          -1.0939e-06, -4.8448e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [168/694 (24%)]	Loss: 0.011415
# ground_truth tensor([33, 33, 60, 33, 32, 60, 60, 35, 33, 33, 60, 37, 40, 40, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 16, 16, 16, 16, 21, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 2.1011e-07, -3.6620e-07,  1.2133e-06,  ...,  2.3319e-07,
#           2.0205e-07,  2.8817e-07],
#         [-4.7554e-06,  2.2778e-06, -4.3281e-06,  ..., -8.1910e-06,
#           8.5347e-06, -1.9682e-07],
#         [-7.1049e-07,  2.8268e-07, -5.2804e-07,  ..., -2.3966e-06,
#           2.2002e-06,  9.4592e-07],
#         ...,
#         [-1.4656e-05,  1.2373e-06, -2.1817e-05,  ..., -1.8680e-05,
#           4.8926e-06, -1.0951e-05],
#         [ 1.2332e-06,  2.1350e-07,  1.7616e-06,  ...,  1.6289e-06,
#          -1.1272e-07,  1.0328e-06],
#         [-2.1513e-06, -4.3512e-07, -1.8686e-06,  ..., -2.1425e-06,
#          -6.0646e-07, -1.0053e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [175/694 (25%)]	Loss: 0.012231
# ground_truth tensor([60, 40, 60, 38, 60, 36, 60, 33, 33, 33, 60, 29, 60, 31, 31], device='cuda:0')
# prediction tensor([ 4, 48, 48, 55, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-2.9858e-08, -5.0077e-07,  4.6054e-07,  ..., -6.5450e-08,
#          -3.6795e-07, -1.8655e-08],
#         [-7.0908e-06,  4.5136e-06, -1.1235e-05,  ..., -1.3501e-05,
#           1.4224e-05,  8.5301e-07],
#         [-5.0345e-07,  2.2175e-07, -6.3025e-07,  ..., -8.2887e-07,
#           7.3931e-07,  1.2774e-07],
#         ...,
#         [-7.8073e-07, -1.0322e-07, -2.1545e-06,  ..., -2.2782e-06,
#           1.0112e-06,  1.0830e-06],
#         [-1.6787e-07,  2.4533e-08, -1.6488e-07,  ..., -2.9696e-07,
#           2.7174e-07,  2.4872e-08],
#         [ 1.0519e-06, -1.0713e-06,  8.4579e-07,  ...,  9.2489e-07,
#          -1.9034e-06, -8.4459e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [182/694 (26%)]	Loss: 0.010070
# ground_truth tensor([60, 28, 60, 29, 60, 31, 60, 29, 60, 28, 60, 26, 26, 26, 60], device='cuda:0')
# prediction tensor([48, 48, 48, 55, 21, 16, 21, 21, 21, 16, 16, 16, 21, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.2699e-08, -8.3097e-07,  6.3735e-07,  ...,  3.3400e-07,
#          -1.7576e-07, -3.9874e-07],
#         [-4.6088e-06,  2.9382e-06, -2.2471e-06,  ..., -6.8040e-06,
#           1.8709e-06,  3.0632e-06],
#         [-9.4493e-07, -7.8619e-07, -1.1842e-06,  ..., -1.4828e-07,
#           2.7823e-07,  2.3859e-07],
#         ...,
#         [-7.3059e-07,  5.1898e-07, -2.4114e-06,  ..., -1.1090e-06,
#           1.3211e-06,  7.7776e-07],
#         [-1.8772e-07,  1.8667e-07, -3.8021e-07,  ..., -1.8126e-07,
#           3.3898e-07,  7.4297e-08],
#         [-3.6357e-09, -5.9619e-07,  6.1416e-07,  ...,  8.5755e-08,
#          -4.2042e-07, -5.6413e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [189/694 (27%)]	Loss: 0.008271
# ground_truth tensor([28, 28, 60, 28, 28, 28, 60, 30, 30, 30, 60, 28, 28, 28, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 3.7831e-07, -7.1878e-07,  6.5257e-07,  ...,  6.6328e-07,
#          -5.7851e-07, -1.7709e-07],
#         [-4.9575e-06,  2.1163e-06, -3.5664e-06,  ..., -4.5581e-06,
#           4.8413e-06,  7.0878e-07],
#         [-1.3106e-06, -5.5526e-07, -2.4513e-06,  ..., -1.0971e-06,
#           1.3555e-06,  4.9562e-07],
#         ...,
#         [-3.9117e-08,  3.9265e-07, -6.7303e-07,  ...,  6.6591e-07,
#          -6.4146e-07,  8.7885e-07],
#         [-8.6769e-08,  3.2481e-08, -2.6863e-07,  ..., -1.7788e-07,
#           2.0426e-07,  1.1061e-08],
#         [ 1.8310e-07, -5.2817e-07,  6.9529e-07,  ...,  7.9556e-07,
#          -8.3448e-07, -2.4223e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [196/694 (28%)]	Loss: 0.009160
# ground_truth tensor([60, 31, 60, 33, 33, 33, 33, 33, 60, 35, 60, 33, 33, 33, 60], device='cuda:0')
# prediction tensor([ 4, 55, 48, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 2.1092e-07, -2.0092e-07,  3.8810e-07,  ...,  7.3461e-07,
#          -3.7212e-07, -3.4378e-08],
#         [ 1.1186e-06,  3.1276e-07, -8.0847e-07,  ...,  3.6013e-06,
#           2.5671e-06, -2.0256e-06],
#         [-2.0307e-06, -1.0255e-06, -2.2943e-06,  ..., -1.8217e-06,
#           1.8199e-06,  4.2114e-07],
#         ...,
#         [ 4.2395e-07,  1.8319e-08,  1.5483e-07,  ...,  4.2198e-07,
#          -3.6296e-07,  3.3665e-07],
#         [-1.3130e-07,  2.5913e-08, -1.7051e-07,  ..., -1.9264e-07,
#           1.3130e-07,  7.6042e-08],
#         [ 6.2949e-07, -1.7051e-07,  2.2336e-07,  ...,  2.2232e-07,
#          -7.7115e-07, -6.2838e-09]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [203/694 (29%)]	Loss: 0.007506
# ground_truth tensor([40, 60, 60, 33, 36, 36, 60, 38, 40, 60, 60, 43, 40, 40, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.7921e-08, -2.0804e-07,  9.9322e-08,  ..., -5.2761e-08,
#          -6.3379e-08, -1.3097e-07],
#         [ 1.8206e-06, -2.4912e-06,  2.4416e-06,  ...,  4.5787e-06,
#          -4.4383e-06, -3.5893e-07],
#         [-5.6997e-07,  4.6348e-07, -1.4257e-06,  ..., -1.6508e-06,
#           1.1958e-06,  7.7542e-07],
#         ...,
#         [-4.1822e-07,  3.5178e-07, -9.4990e-07,  ..., -1.4248e-06,
#          -2.9212e-07,  8.9244e-07],
#         [-2.9277e-07,  1.2853e-07, -1.4554e-07,  ..., -4.6141e-07,
#           2.1446e-07,  8.3924e-08],
#         [-4.3777e-07, -1.9967e-07, -1.1380e-07,  ..., -1.1009e-06,
#           5.4831e-07, -3.2448e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [210/694 (30%)]	Loss: 0.006912
# ground_truth tensor([38, 60, 60, 35, 31, 60, 60, 31, 31, 60, 60, 38, 38, 38, 38], device='cuda:0')
# prediction tensor([11, 48, 55, 12, 12, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 5.8142e-07, -4.8497e-07,  1.1753e-06,  ...,  1.0646e-06,
#          -1.2111e-06,  1.6327e-07],
#         [-1.0472e-07, -1.7612e-08,  2.7477e-08,  ...,  9.1287e-07,
#          -1.0151e-06,  8.6212e-07],
#         [-3.5302e-08,  6.5991e-08, -2.9662e-07,  ...,  3.1299e-07,
#           6.0403e-08,  1.2613e-07],
#         ...,
#         [-4.9074e-08, -7.0420e-07,  3.1504e-07,  ..., -7.7927e-07,
#           7.2060e-08,  2.6191e-07],
#         [-5.0029e-07,  2.8716e-07, -6.0143e-07,  ..., -8.0515e-07,
#           8.5642e-07, -1.6287e-07],
#         [ 3.0311e-07,  8.9265e-08,  3.5035e-07,  ...,  1.3175e-06,
#          -5.8271e-07, -1.5600e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [217/694 (31%)]	Loss: 0.008522
# ground_truth tensor([33, 60, 60, 60, 33, 60, 60, 33, 38, 38, 60, 40, 42, 42, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-5.5560e-08, -1.7946e-07,  4.9576e-08,  ...,  3.1960e-08,
#           4.4825e-07, -3.2269e-07],
#         [ 2.5901e-06, -6.0313e-07,  3.3841e-06,  ...,  3.5626e-06,
#          -6.4775e-06,  1.3302e-06],
#         [-1.3833e-06,  7.7214e-07, -7.2420e-07,  ..., -1.1376e-06,
#           1.7208e-06,  6.1945e-07],
#         ...,
#         [ 4.0003e-07,  8.7434e-07, -1.2940e-06,  ..., -9.3472e-08,
#          -8.7008e-07,  1.2834e-06],
#         [-3.8665e-07,  2.0887e-07, -3.1703e-07,  ..., -6.0128e-07,
#           5.1170e-07,  1.3968e-07],
#         [-8.0113e-07,  7.8664e-07, -2.1705e-06,  ..., -1.6946e-06,
#           1.2561e-06,  1.4793e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [224/694 (32%)]	Loss: 0.007152
# ground_truth tensor([33, 33, 60, 38, 38, 38, 38, 38, 38, 38, 60, 33, 33, 33, 33], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 12, 12, 12, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-7.1556e-08, -5.0534e-07,  2.2522e-07,  ..., -4.1508e-08,
#          -5.0661e-07, -9.9820e-08],
#         [-3.6325e-07,  9.9887e-07, -4.6417e-07,  ..., -1.0097e-06,
#           1.0208e-06,  3.9883e-07],
#         [ 1.7005e-07,  2.2671e-07, -6.7285e-07,  ..., -5.6088e-07,
#          -2.1017e-07,  6.7233e-07],
#         ...,
#         [-3.7568e-08, -1.2674e-07,  1.0688e-06,  ...,  5.4086e-07,
#          -1.8186e-06,  2.6913e-07],
#         [ 2.0311e-07,  8.5553e-07, -9.1636e-07,  ..., -3.5967e-07,
#           1.1395e-06,  4.0962e-07],
#         [ 7.7761e-08, -2.3627e-07,  2.8610e-07,  ..., -1.6427e-07,
#          -4.6278e-07, -4.2871e-08]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [231/694 (33%)]	Loss: 0.007860
# ground_truth tensor([38, 60, 60, 45, 45, 60, 60, 47, 47, 60, 60, 45, 42, 60, 60], device='cuda:0')
# prediction tensor([11, 48, 55, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.5742e-07, -1.1513e-07,  4.1907e-07,  ...,  1.0299e-08,
#          -3.3206e-07, -1.3195e-07],
#         [-1.8383e-07,  7.9267e-07, -3.0487e-06,  ..., -9.5673e-07,
#           2.9838e-06,  7.4762e-08],
#         [ 9.4508e-08,  1.1492e-07, -2.3810e-07,  ..., -2.1973e-07,
#          -9.7774e-10,  1.6165e-07],
#         ...,
#         [ 1.0306e-06,  2.2528e-07,  9.8820e-07,  ...,  1.6896e-06,
#          -2.2297e-06,  7.5806e-07],
#         [ 1.1943e-07,  8.4913e-08, -3.1889e-07,  ...,  6.1514e-08,
#           3.6441e-07,  1.2694e-07],
#         [-9.7051e-08, -4.6103e-07,  5.7322e-07,  ...,  6.8189e-07,
#          -7.9315e-07, -2.7340e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [238/694 (34%)]	Loss: 0.007980
# ground_truth tensor([60, 31, 60, 30, 30, 30, 30, 30, 60, 31, 60, 32, 60, 33, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 12, 12, 12, 12, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 4.1133e-07, -2.8333e-07,  8.1380e-07,  ...,  4.0903e-07,
#          -1.2883e-06, -8.8231e-08],
#         [-4.5371e-07,  3.2097e-06, -1.4482e-06,  ...,  5.6163e-07,
#           4.2014e-06,  9.0103e-07],
#         [ 2.1492e-07, -1.4606e-08, -1.0281e-07,  ...,  6.8627e-07,
#           4.8918e-07,  2.1229e-07],
#         ...,
#         [ 1.7114e-07, -6.8298e-08, -3.2064e-07,  ..., -3.1901e-07,
#          -2.4128e-07,  5.9156e-07],
#         [-7.4648e-08,  1.0515e-07, -4.2154e-07,  ..., -3.2558e-07,
#           2.6164e-07, -2.7931e-09],
#         [-4.9533e-07,  4.9934e-07, -7.0307e-07,  ..., -1.9253e-06,
#           2.0868e-06, -2.6467e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [245/694 (35%)]	Loss: 0.007959
# ground_truth tensor([43, 60, 60, 45, 45, 45, 60, 45, 45, 45, 60, 42, 42, 42, 60], device='cuda:0')
# prediction tensor([ 4, 48, 12, 12, 12, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-2.1141e-07, -4.2521e-08,  7.9023e-08,  ..., -6.0802e-07,
#           3.0710e-07,  6.3278e-09],
#         [-7.9504e-07, -2.6391e-07, -4.1495e-07,  ..., -2.2166e-06,
#          -2.6565e-07,  9.3487e-07],
#         [-2.9774e-07,  9.7283e-07, -3.8304e-06,  ..., -6.9907e-07,
#           2.0014e-06,  7.4544e-07],
#         ...,
#         [ 1.1132e-06,  1.5338e-06, -1.8428e-06,  ...,  2.3489e-06,
#          -9.3161e-07,  1.1506e-06],
#         [ 1.0624e-07,  1.0986e-07, -3.4296e-07,  ...,  3.2249e-08,
#           3.7663e-07,  1.2267e-07],
#         [-2.9666e-07,  2.0069e-07, -1.6432e-06,  ...,  7.7768e-08,
#           4.6499e-07,  2.0964e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [252/694 (36%)]	Loss: 0.007638
# ground_truth tensor([31, 31, 60, 60, 31, 31, 60, 40, 38, 60, 60, 31, 33, 33, 60], device='cuda:0')
# prediction tensor([ 4, 54, 48, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 9.9029e-08, -1.6453e-07,  4.0077e-07,  ..., -6.9548e-08,
#           4.6639e-08, -4.6923e-08],
#         [-1.0193e-06, -3.1350e-07,  2.1618e-06,  ..., -1.6509e-06,
#           2.6473e-06, -1.4112e-06],
#         [-2.4914e-07,  5.3268e-07, -1.6708e-06,  ..., -7.0093e-09,
#           8.1097e-07,  3.9971e-08],
#         ...,
#         [ 2.1786e-07,  9.9553e-07, -1.8805e-06,  ...,  5.6952e-07,
#          -4.5921e-07,  7.3081e-08],
#         [-2.1814e-07, -5.6134e-08, -6.8616e-08,  ..., -1.5602e-07,
#           1.2508e-08, -2.5107e-08],
#         [-8.5005e-07,  1.6766e-07, -1.2236e-06,  ..., -1.5534e-06,
#           1.6804e-06,  2.2934e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [259/694 (37%)]	Loss: 0.007872
# ground_truth tensor([35, 60, 60, 38, 38, 38, 60, 37, 60, 38, 60, 40, 40, 40, 60], device='cuda:0')
# prediction tensor([ 4, 48, 54, 12, 12, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 7.6103e-08,  4.0307e-08,  1.4722e-08,  ...,  2.7199e-08,
#          -9.7500e-08,  4.8146e-08],
#         [ 4.2380e-07, -3.1446e-07,  8.8554e-07,  ...,  1.9520e-07,
#          -1.5233e-06,  6.5573e-07],
#         [-3.3656e-07,  9.5979e-08, -1.5085e-06,  ..., -5.7352e-07,
#           3.6976e-07,  4.8438e-07],
#         ...,
#         [ 4.7476e-07,  4.0490e-07, -4.9101e-07,  ..., -8.6807e-07,
#          -1.7573e-06,  1.8732e-06],
#         [-2.1713e-08, -1.2525e-08, -1.2405e-07,  ...,  1.5434e-07,
#          -2.6572e-08, -5.1633e-09],
#         [ 7.3933e-07, -4.5161e-07,  7.5231e-07,  ...,  8.6418e-07,
#          -1.3093e-06, -1.2668e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [266/694 (38%)]	Loss: 0.007730
# ground_truth tensor([60, 40, 60, 42, 42, 42, 60, 38, 38, 38, 60, 40, 60, 38, 60], device='cuda:0')
# prediction tensor([11, 54, 16, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 1.8821e-07,  5.7716e-08,  1.0130e-07,  ...,  1.0031e-07,
#          -7.2392e-08, -4.9195e-08],
#         [ 2.1231e-06, -2.0740e-06,  4.8533e-06,  ...,  2.4128e-06,
#          -5.3788e-06,  1.5892e-07],
#         [-4.5834e-07,  6.0892e-07, -8.4364e-07,  ...,  5.7994e-08,
#           1.3114e-06,  3.6297e-07],
#         ...,
#         [-3.0794e-07,  9.2337e-07, -9.9071e-07,  ...,  4.0265e-07,
#           3.0719e-07,  4.4187e-07],
#         [-1.0850e-07,  2.6116e-07, -3.8173e-07,  ..., -1.6771e-07,
#           5.9099e-07,  2.0905e-07],
#         [-2.1387e-07,  5.9143e-08, -1.6527e-07,  ..., -1.5023e-07,
#           4.5194e-07, -7.7250e-10]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [273/694 (39%)]	Loss: 0.007832
# ground_truth tensor([45, 45, 60, 40, 40, 40, 60, 40, 40, 40, 60, 38, 60, 40, 60], device='cuda:0')
# prediction tensor([ 4, 16, 16, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.6606e-08,  3.0170e-08,  2.6625e-07,  ...,  1.2682e-07,
#          -3.4440e-07, -6.2879e-08],
#         [ 3.0436e-06, -2.4882e-06,  3.5654e-06,  ...,  4.6642e-06,
#          -5.5640e-06, -9.4344e-07],
#         [-5.9244e-07,  4.4221e-07, -8.0429e-07,  ..., -4.9734e-07,
#           1.2351e-06,  5.2700e-07],
#         ...,
#         [-2.0476e-07,  3.9236e-07, -3.1597e-07,  ...,  2.2500e-07,
#          -1.8325e-07,  3.0789e-07],
#         [-8.2763e-08,  2.1440e-07, -2.9854e-07,  ..., -5.6606e-08,
#           4.2028e-07,  2.2605e-07],
#         [-5.5545e-07,  7.9430e-07, -7.7882e-07,  ..., -7.8684e-07,
#           1.2169e-06,  6.7895e-08]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [280/694 (40%)]	Loss: 0.007279
# ground_truth tensor([35, 60, 60, 40, 40, 60, 60, 40, 42, 60, 60, 40, 40, 60, 60], device='cuda:0')
# prediction tensor([ 4, 48, 54, 12, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-6.4921e-08, -9.9676e-08,  1.2550e-07,  ..., -1.9062e-08,
#          -9.8084e-08, -2.5639e-08],
#         [ 5.0194e-07, -2.1805e-06,  4.6274e-06,  ...,  3.3922e-06,
#          -3.2618e-06, -1.8517e-06],
#         [-5.7496e-07, -2.9952e-07,  6.5802e-07,  ..., -5.0553e-07,
#          -6.5817e-07, -2.1304e-07],
#         ...,
#         [ 9.6464e-07, -4.2128e-07,  4.5218e-07,  ...,  1.1134e-06,
#          -9.2065e-07, -5.0429e-07],
#         [-7.7332e-08,  2.5472e-07, -1.9980e-07,  ..., -4.6643e-07,
#           3.2648e-08,  1.8433e-07],
#         [-6.3124e-08, -1.0033e-06,  9.4243e-07,  ...,  9.5845e-07,
#          -3.4252e-07, -7.6280e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [287/694 (41%)]	Loss: 0.008990
# ground_truth tensor([40, 60, 60, 33, 40, 60, 60, 33, 35, 60, 60, 35, 31, 60, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 3.0701e-07, -1.4891e-07,  5.3647e-07,  ...,  5.6706e-07,
#          -5.4355e-07,  1.1428e-08],
#         [ 1.0524e-06, -3.0544e-06,  9.3120e-06,  ...,  4.2983e-06,
#          -1.0052e-05, -1.6524e-06],
#         [ 2.8892e-07,  1.1049e-07, -7.6523e-07,  ..., -1.7400e-07,
#           1.0259e-06,  4.7362e-07],
#         ...,
#         [ 1.9905e-06, -1.5867e-06,  3.7117e-06,  ...,  3.8067e-06,
#          -4.9184e-06, -2.1142e-07],
#         [ 6.5257e-08,  1.4349e-07, -3.1928e-07,  ..., -1.3645e-08,
#           3.2275e-07,  9.8660e-08],
#         [ 4.1240e-07, -3.9997e-07,  7.4680e-07,  ...,  8.3183e-07,
#          -1.2373e-06,  9.8058e-08]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [294/694 (42%)]	Loss: 0.009149
# ground_truth tensor([34, 60, 60, 34, 33, 60, 60, 33, 33, 33, 60, 34, 34, 60, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 2.0874e-08,  7.2336e-08, -1.5451e-07,  ..., -4.9885e-07,
#           1.6192e-07, -1.2562e-07],
#         [ 3.9726e-06, -5.9241e-07,  3.3918e-06,  ...,  2.4413e-06,
#          -4.9110e-06, -1.6529e-06],
#         [-3.3945e-07, -6.7147e-07, -6.4121e-07,  ..., -2.8227e-07,
#          -3.9497e-07,  2.1464e-07],
#         ...,
#         [ 5.3900e-07, -1.3077e-07,  1.5864e-06,  ...,  1.1843e-06,
#          -2.0209e-06,  1.3860e-07],
#         [-7.8885e-08,  3.2391e-08, -1.0513e-07,  ..., -1.0942e-07,
#           1.7356e-07,  1.6674e-08],
#         [ 2.9311e-07, -1.8549e-08, -5.4386e-08,  ..., -1.9356e-07,
#           1.3219e-07, -1.2259e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [301/694 (43%)]	Loss: 0.007943
# ground_truth tensor([60, 37, 60, 38, 60, 33, 60, 30, 60, 26, 60, 31, 60, 35, 60], device='cuda:0')
# prediction tensor([ 4, 48, 16, 54, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-2.6117e-07, -7.9817e-09,  4.9627e-07,  ...,  4.7804e-08,
#          -3.2279e-07,  6.4737e-09],
#         [ 1.7861e-06, -9.3736e-07, -3.4265e-07,  ..., -1.0912e-06,
#          -9.4057e-07, -3.1109e-07],
#         [ 8.3504e-07,  5.2054e-07, -1.5452e-06,  ..., -7.2137e-07,
#           2.0442e-06,  1.4080e-06],
#         ...,
#         [-1.6117e-06,  1.3668e-06, -1.9019e-06,  ..., -2.9248e-07,
#           2.3742e-06,  7.4634e-07],
#         [-5.4738e-09, -1.4723e-07,  1.0779e-07,  ..., -6.2156e-08,
#          -2.0576e-07,  2.8437e-08],
#         [-4.5941e-07,  4.9081e-07, -2.4763e-06,  ..., -1.5247e-06,
#           2.1248e-06,  1.9864e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [308/694 (44%)]	Loss: 0.007763
# ground_truth tensor([38, 60, 60, 60, 42, 60, 60, 38, 35, 60, 60, 35, 33, 60, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 54, 54, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.9058e-07, -7.9761e-08,  4.8684e-09,  ..., -3.0842e-07,
#           7.3207e-08,  7.6358e-08],
#         [-4.1750e-06, -9.5559e-07, -2.6477e-06,  ..., -5.6805e-06,
#           4.2220e-06,  1.3548e-06],
#         [-2.6894e-06,  3.4335e-08, -1.5469e-06,  ..., -2.4233e-06,
#           2.8725e-06,  1.3291e-06],
#         ...,
#         [-2.3652e-06,  2.9737e-08, -2.6233e-06,  ..., -3.1353e-06,
#           2.2294e-06,  1.1932e-06],
#         [-1.8367e-07,  1.1556e-07, -2.3651e-07,  ..., -2.2000e-07,
#           3.2774e-07,  9.2646e-08],
#         [-2.9571e-08,  2.9822e-07, -4.7829e-07,  ...,  1.0130e-07,
#           3.9276e-07,  3.1707e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [315/694 (45%)]	Loss: 0.008186
# ground_truth tensor([30, 60, 60, 33, 35, 60, 60, 30, 30, 60, 60, 38, 38, 60, 60], device='cuda:0')
# prediction tensor([ 4, 48, 55, 54, 54, 54, 54, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-2.3860e-07, -5.5119e-08,  9.4378e-08,  ..., -4.2396e-07,
#          -6.2574e-09, -8.0891e-08],
#         [-2.3618e-06, -2.2322e-07, -1.7423e-06,  ..., -3.6192e-06,
#           3.2485e-06,  6.8697e-07],
#         [-1.1612e-07,  3.0815e-07, -1.2583e-06,  ..., -4.2783e-07,
#           1.2279e-06,  6.8800e-07],
#         ...,
#         [-3.0817e-07,  3.7379e-07, -7.8093e-07,  ..., -1.5023e-06,
#           1.1145e-06,  7.0741e-07],
#         [ 2.8733e-08, -3.1425e-08,  1.0821e-07,  ...,  2.0603e-07,
#          -1.7407e-07, -4.7106e-09],
#         [-5.5163e-08,  1.4183e-07,  1.5050e-08,  ...,  5.5721e-07,
#          -2.1296e-07,  1.3378e-08]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 1 [322/694 (46%)]	Loss: 0.007545
# ground_truth tensor([33, 33, 60, 34, 34, 34, 60, 35, 35, 35, 35, 35, 35, 35, 60], device='cuda:0')
# prediction tensor([ 4, 48, 48, 55, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 4.0099e-08, -3.1046e-07,  1.6542e-07,  ...,  1.5267e-07,
#           2.9669e-07, -2.6294e-07],
#         [ 1.5977e-07, -2.1407e-06,  2.6653e-06,  ...,  1.8147e-06,
#          -1.0879e-06, -1.6376e-06],
#         [-4.6084e-07, -8.9444e-08, -3.2240e-07,  ..., -7.0188e-07,
#           7.4710e-07, -3.4774e-08],
#         ...,
#         [ 1.9309e-07, -2.8765e-08, -4.2108e-07,  ...,  1.5303e-07,
#          -1.0176e-06,  2.6559e-07],
#         [-9.3277e-08,  6.8554e-08, -6.7255e-08,  ..., -1.0160e-07,
# ...
# ground_truth tensor([60, 33, 60, 35, 36, 60, 60, 33, 35, 60, 60, 31, 33, 60, 60], device='cuda:0')
# prediction tensor([54, 55, 16, 55, 18, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.7487e-07,  4.9114e-07,  1.0417e-07,  ...,  9.8643e-07,
#           1.4711e-07,  2.6040e-07],
#         [-4.0471e-06,  3.1422e-06, -2.9090e-06,  ..., -2.9943e-06,
#           8.0805e-06,  9.9934e-07],
#         [-9.0983e-07,  6.7889e-07, -2.1485e-06,  ..., -2.5748e-06,
#           2.4359e-06,  3.5784e-07],
#         ...,
#         [-2.0981e-06,  4.2765e-06, -4.4077e-06,  ..., -1.5616e-06,
#          -1.0647e-07,  5.0419e-06],
#         [ 3.9689e-07, -7.2587e-08,  5.2973e-07,  ...,  1.2889e-06,
#          -6.1181e-07,  2.0933e-07],
#         [-1.0645e-07,  3.4046e-07, -1.9103e-06,  ..., -1.3371e-06,
#           3.0721e-07,  5.5476e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [378/694 (55%)]	Loss: 0.004808
# ground_truth tensor([60, 36, 60, 35, 35, 35, 60, 38, 60, 35, 60, 31, 31, 31, 60], device='cuda:0')
# prediction tensor([ 4, 54, 16, 55, 18, 16, 16, 16, 16, 55, 16, 55, 16, 55, 16], device='cuda:0')
# lstm gradients:  tensor([[-3.9180e-07,  1.2548e-08, -4.9075e-07,  ..., -3.9617e-07,
#           6.9777e-07, -7.1535e-08],
#         [ 6.9533e-06, -9.3467e-06,  9.4254e-06,  ...,  1.1791e-05,
#          -4.4312e-07, -8.3755e-06],
#         [ 1.4966e-06, -8.8138e-07,  2.6468e-06,  ...,  8.3891e-07,
#          -2.1711e-06, -4.4364e-07],
#         ...,
#         [-1.6436e-06,  3.4277e-06, -7.8760e-06,  ..., -3.4477e-06,
#           4.3121e-06,  8.0651e-07],
#         [-5.5360e-07,  4.1428e-07, -6.5217e-07,  ..., -1.8887e-06,
#           1.7771e-06,  3.7567e-07],
#         [-1.1111e-06,  2.6862e-07, -3.7710e-07,  ..., -2.7001e-06,
#           3.2312e-06, -2.8019e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [385/694 (56%)]	Loss: 0.004941
# ground_truth tensor([28, 60, 26, 60, 33, 60, 38, 60, 38, 60, 40, 60, 33, 60, 37], device='cuda:0')
# prediction tensor([ 4, 55, 55, 55, 16, 16, 16, 16, 16, 16, 16, 16, 55, 16, 55], device='cuda:0')
# lstm gradients:  tensor([[ 4.4177e-07, -2.5034e-08,  3.1789e-07,  ...,  7.0584e-07,
#          -5.8500e-07, -6.3873e-09],
#         [ 9.8430e-06, -2.2301e-06,  8.9854e-06,  ...,  1.6990e-05,
#          -1.3128e-05, -1.3422e-06],
#         [ 3.1076e-07, -1.6901e-07,  4.4952e-07,  ...,  8.0847e-07,
#          -1.0209e-06,  1.3187e-07],
#         ...,
#         [-1.5408e-06,  1.5273e-06, -4.1177e-06,  ...,  8.6126e-08,
#           1.8485e-06, -5.1034e-07],
#         [ 2.4881e-07, -3.0837e-07,  5.5120e-07,  ..., -7.5801e-07,
#          -1.3253e-07,  4.9959e-07],
#         [-1.2200e-06, -3.4966e-07, -5.1757e-07,  ..., -2.2305e-06,
#           9.2051e-07,  4.5131e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [392/694 (57%)]	Loss: 0.005467
# ground_truth tensor([38, 38, 60, 40, 41, 41, 60, 43, 45, 45, 60, 60, 38, 60, 60], device='cuda:0')
# prediction tensor([ 4, 16, 55, 55, 18,  8, 12, 16, 18,  8, 16, 16, 18, 16, 18], device='cuda:0')
# lstm gradients:  tensor([[ 3.7912e-07,  7.6954e-08,  3.6066e-07,  ...,  6.1020e-07,
#          -6.0764e-07, -1.2608e-07],
#         [ 5.7318e-06, -1.5198e-06,  8.2932e-06,  ...,  1.2577e-05,
#          -9.5127e-06, -2.4341e-06],
#         [ 7.1338e-08,  8.1296e-07,  2.8072e-07,  ...,  1.4660e-06,
#           2.7863e-07,  5.2776e-07],
#         ...,
#         [-9.5064e-07,  2.7839e-06, -1.2430e-06,  ..., -4.1412e-06,
#           4.2798e-06,  1.6063e-07],
#         [ 7.2027e-07, -4.2871e-07, -2.8296e-07,  ..., -4.7438e-07,
#          -2.5716e-07, -1.6288e-07],
#         [-1.9615e-06,  1.0089e-06, -4.8352e-06,  ..., -6.3028e-06,
#           4.3391e-06,  1.1165e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [399/694 (58%)]	Loss: 0.005200
# ground_truth tensor([38, 60, 60, 30, 30, 60, 60, 31, 31, 60, 60, 33, 35, 60, 60], device='cuda:0')
# prediction tensor([ 4, 54, 55, 55, 55, 18, 16, 16, 16, 18, 16, 16, 16, 18, 16], device='cuda:0')
# lstm gradients:  tensor([[-8.0756e-08, -2.1855e-07,  3.8664e-07,  ...,  5.1715e-07,
#          -8.7931e-07,  1.8716e-07],
#         [-7.2559e-07, -9.8062e-07, -1.2226e-06,  ..., -8.4415e-07,
#           1.0573e-07, -1.4060e-07],
#         [-1.2990e-06,  1.9873e-07, -2.1097e-06,  ..., -3.2799e-06,
#           2.0831e-06,  7.9504e-07],
#         ...,
#         [ 2.9687e-06,  1.6463e-07,  6.2244e-06,  ...,  4.3461e-06,
#           1.4638e-06, -2.1688e-06],
#         [ 1.1379e-06, -9.6551e-07,  1.8785e-06,  ...,  2.2445e-06,
#          -4.1103e-07, -1.6851e-06],
#         [-6.9474e-07,  7.3738e-07, -1.0765e-06,  ..., -2.3706e-06,
#           2.7777e-06,  1.8820e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [406/694 (59%)]	Loss: 0.005340
# ground_truth tensor([40, 40, 40, 60, 40, 60, 60, 33, 40, 60, 60, 33, 35, 60, 60], device='cuda:0')
# prediction tensor([ 4, 18, 55, 55,  0, 18, 16, 16, 16, 18, 16, 16,  0, 18, 55], device='cuda:0')
# lstm gradients:  tensor([[-1.0145e-07,  5.2783e-07, -6.9543e-07,  ...,  4.2375e-07,
#           6.3400e-07,  2.4609e-07],
#         [ 1.3856e-06, -2.0974e-06,  4.4710e-06,  ...,  1.7557e-06,
#          -5.7612e-06, -6.2674e-07],
#         [ 1.2723e-06, -2.8831e-07,  4.8980e-07,  ...,  2.3395e-06,
#          -1.8653e-06,  6.1363e-07],
#         ...,
#         [-5.4268e-06,  1.3614e-06, -6.6305e-06,  ..., -5.9601e-06,
#           8.6516e-06, -2.1176e-07],
#         [-4.0630e-07,  2.9812e-07, -1.6737e-06,  ..., -1.7855e-06,
#           1.2266e-06,  8.1830e-07],
#         [-1.0392e-06,  4.2434e-07, -1.5701e-06,  ..., -1.9908e-06,
#           3.0384e-06, -7.1224e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [413/694 (60%)]	Loss: 0.004809
# ground_truth tensor([60, 43, 60, 45, 45, 45, 60, 42, 42, 42, 60, 38, 38, 38, 60], device='cuda:0')
# prediction tensor([ 4, 54, 18, 55, 16, 55, 16, 16, 16, 55, 16, 55, 16,  0, 18], device='cuda:0')
# lstm gradients:  tensor([[ 3.7778e-07,  7.3906e-07, -3.3422e-07,  ..., -4.2675e-07,
#           8.0865e-07, -1.1252e-07],
#         [ 4.0134e-07, -2.3261e-06,  3.4698e-06,  ...,  3.4590e-06,
#          -2.0080e-06, -2.2858e-06],
#         [ 2.4475e-06,  1.4303e-06,  2.4745e-06,  ...,  1.0833e-06,
#          -1.5289e-06, -6.4114e-07],
#         ...,
#         [ 1.2191e-06,  1.4509e-06, -3.9606e-06,  ..., -2.2631e-06,
#          -9.4471e-07,  2.9407e-06],
#         [-5.7562e-07,  1.0426e-07, -9.8009e-07,  ..., -1.0465e-06,
#           1.5637e-06, -1.4862e-07],
#         [ 1.9864e-07, -4.5829e-08, -6.6048e-07,  ...,  3.7105e-07,
#           5.5148e-08, -2.1312e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [420/694 (61%)]	Loss: 0.004296
# ground_truth tensor([35, 60, 60, 38, 38, 60, 60, 30, 30, 60, 60, 31, 31, 60, 60], device='cuda:0')
# prediction tensor([ 4, 16,  4, 55,  0,  8, 55, 16, 18, 18, 12, 16, 16, 16, 16], device='cuda:0')
# lstm gradients:  tensor([[ 3.7085e-07, -7.8455e-08,  4.1632e-07,  ..., -1.0871e-08,
#          -8.4073e-07,  1.7739e-08],
#         [ 7.0851e-08,  1.2527e-06, -6.9006e-07,  ..., -4.7699e-06,
#          -5.6163e-06,  2.7028e-06],
#         [ 1.0761e-06,  4.8799e-07,  5.3461e-07,  ...,  2.4508e-07,
#          -1.3494e-06, -2.5419e-07],
#         ...,
#         [ 3.5614e-06, -2.4787e-06,  6.1229e-06,  ...,  2.9906e-06,
#          -6.4552e-06, -2.6735e-06],
#         [ 9.3677e-09,  6.8142e-07,  2.7280e-07,  ...,  7.9997e-08,
#           3.3928e-07,  3.1745e-07],
#         [ 6.1238e-08, -1.5318e-07,  3.2410e-07,  ..., -1.5801e-07,
#          -3.8837e-08, -1.3981e-08]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [427/694 (62%)]	Loss: 0.005549
# ground_truth tensor([29, 60, 60, 36, 36, 60, 60, 34, 36, 60, 60, 36, 36, 60, 60], device='cuda:0')
# prediction tensor([11, 54, 15, 55, 18, 18, 16, 16, 18, 18, 16, 16, 18, 12, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.2647e-06, -2.6056e-07, -2.1617e-07,  ...,  6.5313e-07,
#           9.2376e-07,  7.4892e-07],
#         [-3.9972e-06,  3.9412e-06, -4.3246e-06,  ..., -4.9117e-06,
#           3.3452e-06,  4.2860e-06],
#         [-7.5842e-07, -6.9415e-07, -1.0515e-06,  ..., -1.7345e-06,
#           1.3979e-06, -3.5751e-07],
#         ...,
#         [ 1.6136e-06,  1.5615e-06,  5.3250e-06,  ...,  4.6353e-06,
#          -4.5219e-06,  8.5240e-07],
#         [ 6.7990e-07, -1.6961e-06,  9.9769e-07,  ...,  8.7003e-07,
#          -9.8579e-07, -1.2932e-06],
#         [ 8.6143e-07, -3.9237e-07,  7.1493e-07,  ...,  1.0490e-06,
#          -1.1063e-06, -8.1275e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [434/694 (63%)]	Loss: 0.006095
# ground_truth tensor([41, 41, 60, 60, 41, 60, 60, 38, 40, 40, 60, 37, 33, 33, 60], device='cuda:0')
# prediction tensor([ 4, 16, 18, 55, 18,  8, 12, 16, 20, 12, 16, 16,  8,  0, 16], device='cuda:0')
# lstm gradients:  tensor([[ 6.0589e-07, -4.4233e-07,  1.3384e-06,  ...,  1.5791e-06,
#          -2.5534e-06, -1.8337e-07],
#         [ 5.8840e-07, -2.5644e-07, -9.7572e-07,  ..., -9.5611e-07,
#           1.3820e-06,  9.0697e-07],
#         [ 4.4210e-07,  9.6669e-07, -4.7071e-07,  ...,  9.8392e-08,
#           1.5409e-06,  6.3027e-07],
#         ...,
#         [ 1.3169e-06,  1.8470e-06, -3.6467e-06,  ...,  1.3214e-06,
#           1.8633e-06,  2.1112e-06],
#         [ 1.9773e-06, -3.1494e-06,  5.3412e-06,  ...,  4.3555e-06,
#          -7.6313e-06, -2.1587e-06],
#         [ 2.2681e-06, -2.0443e-06,  3.5988e-06,  ...,  4.1560e-06,
#          -2.9942e-06, -1.8798e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [441/694 (64%)]	Loss: 0.005984
# ground_truth tensor([38, 38, 60, 38, 37, 37, 60, 33, 35, 60, 60, 35, 33, 60, 60], device='cuda:0')
# prediction tensor([ 4, 16, 55, 55, 12,  8, 16, 55, 16, 55, 12, 16, 16,  0, 12], device='cuda:0')
# lstm gradients:  tensor([[-3.2859e-07,  4.5778e-07, -8.0113e-07,  ..., -8.0305e-07,
#           9.7250e-07, -7.3246e-08],
#         [ 1.6611e-06,  3.3835e-06, -2.0827e-06,  ..., -2.5652e-06,
#           5.3677e-06, -4.8638e-07],
#         [-1.7862e-06, -4.6316e-07, -1.3028e-06,  ..., -7.7352e-08,
#           5.1821e-08,  1.1905e-06],
#         ...,
#         [-4.2657e-06,  1.2422e-06, -1.9707e-06,  ..., -3.1123e-06,
#           6.8231e-06,  9.4663e-07],
#         [ 7.5592e-07, -5.9059e-07, -1.2562e-06,  ..., -7.6519e-07,
#           5.9782e-07, -2.1918e-07],
#         [ 2.2750e-06, -2.1015e-06,  1.7440e-06,  ...,  2.2292e-06,
#          -3.9039e-06, -1.6547e-06]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [448/694 (65%)]	Loss: 0.004495
# ground_truth tensor([31, 60, 60, 60, 31, 60, 60, 36, 38, 60, 60, 60, 38, 60, 60], device='cuda:0')
# prediction tensor([ 4, 54, 55, 55,  0, 18,  4, 16,  0, 12, 16, 16,  0, 12, 12], device='cuda:0')
# lstm gradients:  tensor([[-6.1961e-07,  4.0636e-09,  1.0164e-06,  ...,  6.3112e-07,
#          -5.3274e-07, -1.5570e-07],
#         [ 1.8359e-06, -3.7417e-07,  1.0050e-06,  ..., -9.1450e-07,
#          -8.8444e-06,  4.8803e-06],
#         [ 2.8661e-07,  1.5478e-07,  8.8506e-07,  ..., -8.4260e-07,
#          -1.0903e-06,  1.5552e-08],
#         ...,
#         [ 1.0960e-06, -2.2537e-06,  1.7495e-06,  ...,  3.6522e-06,
#          -3.1275e-06, -2.6223e-06],
#         [ 3.4744e-07, -8.4761e-07,  2.0297e-06,  ...,  3.1383e-07,
#          -2.8204e-06, -6.5811e-07],
#         [-6.7677e-07, -2.4584e-07, -1.7309e-06,  ..., -1.1864e-06,
#           1.5274e-06, -5.3571e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [455/694 (66%)]	Loss: 0.005788
# ground_truth tensor([38, 38, 60, 43, 43, 43, 60, 38, 38, 38, 60, 35, 35, 35, 60], device='cuda:0')
# prediction tensor([ 4, 54, 16, 55, 18, 55, 12, 55,  8,  8,  8, 55, 16,  6, 12], device='cuda:0')
# lstm gradients:  tensor([[ 9.3449e-07, -6.3145e-07,  9.5160e-07,  ...,  1.0050e-06,
#          -1.1109e-06, -4.6690e-07],
#         [ 5.5914e-06, -1.1380e-06,  8.3745e-06,  ...,  5.6202e-06,
#          -1.1133e-05,  2.3848e-06],
#         [-1.5951e-07,  4.4609e-07, -3.7977e-07,  ...,  3.3211e-07,
#           1.5557e-06,  1.5117e-07],
#         ...,
#         [-3.2683e-07, -1.5416e-06,  4.6320e-06,  ..., -1.0036e-06,
#          -2.3050e-06, -7.8364e-07],
#         [ 3.4265e-07, -2.3973e-07,  1.1248e-06,  ...,  1.3836e-06,
#          -1.0335e-06, -1.7725e-07],
#         [ 2.7173e-07, -1.7119e-07,  3.4624e-07,  ...,  9.0700e-07,
#          -8.3072e-07, -4.7269e-08]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [462/694 (67%)]	Loss: 0.004619
# ground_truth tensor([60, 28, 60, 30, 60, 33, 60, 35, 35, 35, 60, 33, 60, 35, 60], device='cuda:0')
# prediction tensor([50, 55, 16, 15, 18, 55, 16, 55, 16, 15, 16, 16, 16, 55, 18], device='cuda:0')
# lstm gradients:  tensor([[ 1.6246e-06,  7.6421e-07,  5.0113e-07,  ...,  2.0325e-06,
#          -5.5834e-07, -1.8630e-07],
#         [ 2.9227e-06, -2.6960e-06,  6.9009e-06,  ...,  1.1752e-05,
#          -1.2017e-05, -9.2276e-07],
#         [ 5.1029e-08, -2.7251e-08,  3.4625e-07,  ...,  1.6246e-07,
#           9.2069e-07, -5.3790e-07],
#         ...,
#         [ 2.2233e-06, -8.2143e-07,  2.4063e-06,  ...,  7.4569e-06,
#          -7.7073e-06,  2.0097e-06],
#         [-1.8013e-06,  9.7677e-07, -2.7771e-06,  ..., -3.8375e-06,
#           5.2003e-06, -6.6662e-07],
#         [-1.5044e-06, -1.2986e-07, -1.2904e-06,  ..., -2.8278e-06,
#           3.5366e-06, -5.1850e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [469/694 (68%)]	Loss: 0.005061
# ground_truth tensor([60, 28, 28, 60, 33, 33, 60, 60, 60, 60, 60, 60, 33, 33, 60], device='cuda:0')
# prediction tensor([ 4, 18, 18, 16, 16,  0, 16, 55, 16,  0, 18, 16, 16,  0, 16], device='cuda:0')
# lstm gradients:  tensor([[-1.3969e-07,  1.2143e-07, -1.9149e-07,  ..., -2.4907e-07,
#           5.2643e-07, -2.8087e-08],
#         [-2.5202e-07,  1.6809e-06, -5.2192e-06,  ..., -2.9341e-06,
#           5.2541e-06,  1.3179e-06],
#         [-4.9984e-07, -2.4673e-07, -1.1444e-06,  ..., -8.2858e-07,
#          -7.3200e-07,  8.6671e-07],
#         ...,
#         [ 1.4613e-06,  4.6812e-07,  5.4855e-06,  ...,  5.4187e-06,
#          -6.0268e-06, -6.8581e-07],
#         [ 1.7394e-07, -2.4984e-07, -4.3752e-07,  ..., -3.4151e-07,
#           3.6733e-07,  1.4493e-08],
#         [ 1.7477e-07, -2.2330e-08, -6.8809e-07,  ...,  1.3663e-07,
#          -5.4899e-07,  5.7507e-07]], device='cuda:0', dtype=torch.float64)
# prediction:  torch.Size([7, 15, 61]) ground_truth:  torch.Size([7, 15, 61])
# Train Epoch: 3 [476/694 (69%)]	Loss: 0.005026
# ground_truth tensor([60, 42, 60, 43, 43, 43, 60, 31, 31, 31, 60, 31, 31, 31, 60], device='cuda:0')
# prediction tensor([ 4, 54, 16, 55, 18, 12, 12, 16, 16,  0, 51, 16, 16,  0, 16], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7ebffb34db9f> in <module>()
#       9 for epoch in range(1, epochs + 1):
#      10     #train
# ---> 11     current_train_loss = (train(epoch))
#      12     train_losses.append(current_train_loss)
#      13     #test
#
# <ipython-input-10-9f94574d2f99> in train(epoch)
#       8         input_lstm, ground_truth, seq_lengths = reorderBatch(data)
#       9         prediction = model(input_lstm.double().to(device), seq_lengths)
# ---> 10         ground_truth = ground_truth.to(device)
#      11
#      12         #print('inptu_lstm: ', input_lstm.size())
#
# KeyboardInterrupt:

# %% [markdown]
# # Generate

# %%
np.set_printoptions(threshold=np.inf, suppress=1)

# %%
model.eval()
model.batch_size=1
with torch.no_grad():
    #get unseeen sample from validation set
    for data in val_loader:
        input_lstm, ground_truth, seq_lengths = reorderBatch(data)
        print(input_lstm.size())
        prediction = model(input_lstm.double().to(device), seq_lengths)
        print(prediction.size())
        


        prediction = prediction.squeeze(0).cpu().numpy()
        #batch size must be 1 for generation
        prediction = prediction[:,0:1].reshape(input_lstm.size(1),input_lstm.size(2))
        
        print(prediction.shape)

        #normalize to [0,1]
        pred_max = np.max(prediction)
        pred_min = np.min(prediction)
        prediction = (prediction - pred_min) / (pred_max - pred_min)
        #print(prediction)
        
        prediction[prediction < 0.7] = 0
        
        prediction = debinarizeMidi(prediction, prediction=True)
        prediction = addCuttedOctaves(prediction)
        #print(prediction)
        pianorollMatrixToTempMidi(prediction, show=True, showPlayer=True, autoplay=True,
                                 path='../temp/temp.mid')
        

print('')
