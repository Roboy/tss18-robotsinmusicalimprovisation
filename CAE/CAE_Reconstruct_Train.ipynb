# %%
import numpy as np
import glob
import pypianoroll as ppr
import time
import music21
import os
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from utils.utils import *
#np.set_printoptions(threshold=np.inf)
#torch.set_printoptions(threshold=50000)

# %%
##################################
#HYPERPARAMS
##################################
epochs = 1
learning_rate = 5e-4
batch_size= 98
log_interval = 1  #Log/show loss per batch

# %% [markdown]
# # Load MIDI files from npz

# %%
data = np.load('../WikifoniaPartlyNoTranspose.npz')

midiDatasetTrain = data['train']
midiDatasetTest = data['test']

data.close()

"""
print("Training set: ({}, {}, {}, {})".format(midiDatasetTrain.size()[0],
                                                midiDatasetTrain.size()[1],
                                                midiDatasetTrain.size()[2],
                                                midiDatasetTrain.size()[3]))
print("Test set: ({}, {}, {}, {})".format(midiDatasetTest.size()[0],
                                                midiDatasetTest.size()[1],
                                                midiDatasetTest.size()[2],
                                                midiDatasetTest.size()[3]))
"""

print("Training set: {}".format(midiDatasetTrain.shape))
print("Test set: {}".format(midiDatasetTest.shape))
# Out:
# Training set: (4056, 1, 96, 60)
# Test set: (1034, 1, 96, 60)

# %%
#print(getSlicedPianorollMatrix('WikifoniaServer/train80/Ahmad-Jamal---Poinciana.mid').shape)

# %%
fullPitch = 128
_, _, length, reducedPitch = midiDatasetTrain.shape

# %% [markdown]
# # CDVAE

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
midiDatasetTrain = torch.from_numpy(midiDatasetTrain)#.float()
trainLoader = torch.utils.data.DataLoader(midiDatasetTrain, batch_size=batch_size, shuffle=True, drop_last=True)

midiDatasetTest = torch.from_numpy(midiDatasetTest)#.float()
testLoader = torch.utils.data.DataLoader(midiDatasetTest, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
class CDVAE(nn.Module):
    def __init__(self):
        super(CDVAE, self).__init__()
        
        ###ENCODER###
        self.encode1 = nn.Sequential(
            nn.Conv2d(1,100,(16,5),stride=(16,5),padding=0),
            nn.BatchNorm2d(100),
            nn.ELU(),
            nn.Conv2d(100,200,(2,1),stride=(2,1),padding=0),
            nn.BatchNorm2d(200),
            nn.ELU(),
            nn.Conv2d(200,400,(2,2),stride=(1,2),padding=0),
            nn.BatchNorm2d(400),
            nn.ELU(),
            nn.Conv2d(400,800,(2,2),stride=(2,2),padding=0),
            nn.BatchNorm2d(800),
            nn.ELU()
        )
            
        self.encode2 = nn.Sequential(
            nn.Linear(2400,800),
            nn.BatchNorm1d(800),
            nn.ELU(),
            nn.Linear(800,400),
            nn.BatchNorm1d(400),
            nn.ELU(),
            nn.Linear(400,100),
            nn.BatchNorm1d(100),
            nn.ELU()
        )

        ###DECODER###
        self.decode1 = nn.Sequential(
            nn.Linear(100,400),
            nn.BatchNorm1d(400),
            nn.ELU(),
            nn.Linear(400,800),
            nn.BatchNorm1d(800),
            nn.ELU(),
            nn.Linear(800,2400),
            nn.BatchNorm1d(2400),
            nn.ELU()
        )
        self.decode2 = nn.Sequential(
            nn.ConvTranspose2d(800,400,(2,2),stride=(2,2),padding=0),
            nn.BatchNorm2d(400),
            nn.ELU(),
            nn.ConvTranspose2d(400,200,(2,2),stride=(1,2),padding=0),
            nn.BatchNorm2d(200),
            nn.ELU(),
            nn.ConvTranspose2d(200,100,(2,1),stride=(2,1),padding=0),
            nn.BatchNorm2d(100),
            nn.ELU(),
            nn.ConvTranspose2d(100,1,(16,5),stride=(16,5),padding=0),
            nn.BatchNorm2d(1),
            nn.ELU()
        )
    
    def encoder(self, x):
        #print("ENOCDER")
        hEnc = self.encode1(x)
        hEnc = torch.squeeze(hEnc,3).view(-1,800*3)
        hEnc = self.encode2(hEnc)
        return hEnc

    def decoder(self, z):
        #print("DECODER")
        hDec = self.decode1(z)
        hDec = hDec.view(hDec.size()[0],800,-1).unsqueeze(2)
        hDec = self.decode2(hDec)
        return hDec

    def forward(self, x):
        mu = self.encoder(x)
        return self.decoder(mu), mu
    
model = CDVAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


def loss_function(recon_x, x, mu, dataset):
    
    cos = nn.CosineSimilarity(dim=1, eps=1e-8) 
    
    ###NESTED COSINE SIMILARITY SOFTMAX LOSS 
    ###WITH 4 RANDOM RECONSTRUCTED VECTORS
    ###WHICH INCLUDES NEGATIVE EXAMPLES OF RECONSTRUCTIONS
    if(False):#model.training): 
        sftmax = nn.Softmax(dim=0)
        lenDataset = dataset.size()[0]
        #print(lenDataset)
        softmax = 0
        for orgInput, recon in zip(x, recon_x):
                     
            #HAVE TO DO IT LIKE THIS BECAUSE BATCHSIZE 1 DOESN'T WORK IN PYTORCH
            rand = np.random.randint(0,lenDataset-1)
            randomRecons = dataset[rand:rand+1,:,:,:] 
            for i in range(3):
                rand = np.random.randint(0,lenDataset-1)
                randomTemp = dataset[rand:rand+1,:,:,:]
                randomRecons = torch.cat((randomRecons,randomTemp),dim=0)
            with torch.no_grad():
                randomRecons, _ = model(randomRecons.float().to(device))
            #COMPUTE COSINE SIMILARITY FOR ORIGINAL INPUT
            #AND ITS RECONSTRUCTION
            cosSimOrg = cos(orgInput.view(1,-1),recon.view(1,-1))
            print(cosSimOrg)
            
            #INCLUDE NEGATIVE EXAMPLES WITH SOFTMAX
            cosSim = cos(orgInput.view(1,-1),randomRecons[0].view(1,-1))
            for randomRecon in randomRecons[1:]:
                cosTemp = cos(orgInput.view(1,-1),randomRecon[0].view(1,-1))
                cosSim = torch.cat((cosSim, cosTemp),dim=0)
            cosSoftmax = torch.cat((cosSimOrg,cosSim),dim=0)            
            softmax += sftmax(cosSoftmax)[0]
        
        return softmax
    #OLDLOSS JUST COSINE SIMILARITY ON RECONSTRUCTION (GOOD FOR TESTING?)
    else:     
        cosSim = 0
        for datapoint, recon in zip(x, recon_x):
            cosTemp = cos(datapoint.view(1,-1),recon.view(1,-1))
            cosSim += cosTemp
            
        #print(cosSim)
        return x.size()[0]-cosSim
        

def train(epoch):
    model.train()
    trainLoss = 0

    for batch_idx, data in enumerate(trainLoader):
        ###DENOISING AUTOENCODER
        #data = data.float().to(device)
        #noise = torch.bernoulli((torch.rand_like(data))).to(device)
        #noisyData = data+noise
        #optimizer.zero_grad()
        #reconBatch, mu = model(noisyData)
        ###
        
        ###NORMAL AUTOENCODER
        data = data.float().to(device)
        optimizer.zero_grad()
        reconBatch, mu = model(data)
        ###
        
        loss = loss_function(reconBatch, data, mu, trainLoader.dataset)
        loss.backward()
        trainLoss += loss.item()
        optimizer.step()
        if(batch_idx % log_interval == 0):
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(trainLoader.dataset),
                100. * batch_idx / len(trainLoader),
                loss.item() / len(data)))
        #if (batch_idx == 10):
        #    break

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, trainLoss / len(trainLoader.dataset)))

def test(epoch):
    model.eval()
    testLoss = 0
    with torch.no_grad():
        for i, data in enumerate(testLoader):
            ###DENOISING AUTOENCODER
            #data = data.float().to(device)
            #noise = torch.bernoulli((torch.rand_like(data))).to(device)
            #noisyData = data+noise
            #reconBatch, mu = model(noisyData)
            ###
            
            ###NORMAL AUTOENCODER
            data = data.float().to(device)
            reconBatch, mu = model(data)
            
            #TEMP
            randomRecons = torch.zeros(1,1,60,96).to(device)
            #TEMP END
            testLoss += loss_function(reconBatch, data, mu, randomRecons).item()
            
            #if(i==10):
            #    break
    testLoss /= len(testLoader.dataset)

    print('====> Test set loss: {:.4f}'.format(testLoss))

# %%
"""
#LOAD MODEL
pathToModel = 'model/YamahaPianoCompetition2002Transposedby60_10Epochs.model'

try:
    #LOAD TRAINED MODEL INTO GPU
    if(torch.cuda.is_available()):
        model = torch.load(pathToModel)
        
    #LOAD MODEL TRAINED ON GPU INTO CPU
    else:
        model = torch.load(pathToModel, map_location=lambda storage, loc: storage)
    print("\n--------model restored--------\n")
except:
    print("\n--------no saved model found--------\n")
"""
print('')

# %%
for epoch in range(1, epochs + 1):
    train(epoch)
    test(epoch)
# Out:
# tensor([0.0045], grad_fn=<DivBackward1>)
# tensor([0.0054], grad_fn=<DivBackward1>)
# tensor([0.0039], grad_fn=<DivBackward1>)
# tensor([-0.0127], grad_fn=<DivBackward1>)
# tensor([0.0094], grad_fn=<DivBackward1>)
# tensor([-0.0035], grad_fn=<DivBackward1>)
# tensor([-0.0136], grad_fn=<DivBackward1>)
# tensor([0.0005], grad_fn=<DivBackward1>)
# tensor([0.0164], grad_fn=<DivBackward1>)
# tensor([0.0029], grad_fn=<DivBackward1>)
# tensor([0.0203], grad_fn=<DivBackward1>)
# tensor([-0.0020], grad_fn=<DivBackward1>)
# tensor([-0.0066], grad_fn=<DivBackward1>)
# tensor([0.0043], grad_fn=<DivBackward1>)
# tensor([-0.0204], grad_fn=<DivBackward1>)
# tensor([-0.0105], grad_fn=<DivBackward1>)
# tensor([0.0077], grad_fn=<DivBackward1>)
# tensor([0.0203], grad_fn=<DivBackward1>)
# tensor([0.0077], grad_fn=<DivBackward1>)
# tensor([-0.0064], grad_fn=<DivBackward1>)
# tensor([-0.0013], grad_fn=<DivBackward1>)
# tensor([0.0073], grad_fn=<DivBackward1>)
# tensor([-0.0087], grad_fn=<DivBackward1>)
# tensor([-0.0103], grad_fn=<DivBackward1>)
# tensor([0.0004], grad_fn=<DivBackward1>)
# tensor([0.0259], grad_fn=<DivBackward1>)
# tensor([-0.0051], grad_fn=<DivBackward1>)
# tensor([0.0102], grad_fn=<DivBackward1>)
# tensor([0.0078], grad_fn=<DivBackward1>)
# tensor([-0.0116], grad_fn=<DivBackward1>)
# tensor([-0.0210], grad_fn=<DivBackward1>)
# tensor([-0.0199], grad_fn=<DivBackward1>)
# tensor([-0.0048], grad_fn=<DivBackward1>)
# tensor([0.0021], grad_fn=<DivBackward1>)
# tensor([0.0259], grad_fn=<DivBackward1>)
# tensor([0.0074], grad_fn=<DivBackward1>)
# tensor([0.0185], grad_fn=<DivBackward1>)
# tensor([0.0152], grad_fn=<DivBackward1>)
# tensor([-0.0040], grad_fn=<DivBackward1>)
# tensor([0.0272], grad_fn=<DivBackward1>)
# tensor([-0.0132], grad_fn=<DivBackward1>)
# tensor([-0.0159], grad_fn=<DivBackward1>)
# tensor([0.0095], grad_fn=<DivBackward1>)
# tensor([-0.0080], grad_fn=<DivBackward1>)
# tensor([0.0011], grad_fn=<DivBackward1>)
# tensor([-0.0005], grad_fn=<DivBackward1>)
# tensor([-0.0185], grad_fn=<DivBackward1>)
# tensor([0.0053], grad_fn=<DivBackward1>)
# tensor([0.0242], grad_fn=<DivBackward1>)
# tensor([-0.0071], grad_fn=<DivBackward1>)
# tensor([0.0110], grad_fn=<DivBackward1>)
# tensor([0.0029], grad_fn=<DivBackward1>)
# tensor([-0.0068], grad_fn=<DivBackward1>)
# tensor([0.0079], grad_fn=<DivBackward1>)
# tensor([0.0101], grad_fn=<DivBackward1>)
# tensor([-0.0212], grad_fn=<DivBackward1>)
# tensor([0.0121], grad_fn=<DivBackward1>)
# tensor([0.0154], grad_fn=<DivBackward1>)
# tensor([-0.0130], grad_fn=<DivBackward1>)
# tensor([-0.0109], grad_fn=<DivBackward1>)
# tensor([0.0022], grad_fn=<DivBackward1>)
# tensor([-0.0032], grad_fn=<DivBackward1>)
# tensor([-0.0083], grad_fn=<DivBackward1>)
# tensor([-0.0102], grad_fn=<DivBackward1>)
# tensor([-0.0073], grad_fn=<DivBackward1>)
# tensor([-0.0085], grad_fn=<DivBackward1>)
# tensor([0.0082], grad_fn=<DivBackward1>)
# tensor([-0.0002], grad_fn=<DivBackward1>)
# tensor([-0.0232], grad_fn=<DivBackward1>)
# tensor([0.0028], grad_fn=<DivBackward1>)
# tensor([-0.0085], grad_fn=<DivBackward1>)
# tensor([0.0086], grad_fn=<DivBackward1>)
# tensor([0.0043], grad_fn=<DivBackward1>)
# tensor([-0.0030], grad_fn=<DivBackward1>)
# tensor([0.0164], grad_fn=<DivBackward1>)
# tensor([0.0141], grad_fn=<DivBackward1>)
# tensor([0.0092], grad_fn=<DivBackward1>)
# tensor([-0.0058], grad_fn=<DivBackward1>)
# tensor([-0.0020], grad_fn=<DivBackward1>)
# tensor([0.0073], grad_fn=<DivBackward1>)
# tensor([-0.0159], grad_fn=<DivBackward1>)
# tensor([-0.0210], grad_fn=<DivBackward1>)
# tensor([0.0023], grad_fn=<DivBackward1>)
# tensor([0.0028], grad_fn=<DivBackward1>)
# tensor([-0.0183], grad_fn=<DivBackward1>)
# tensor([-0.0053], grad_fn=<DivBackward1>)
# tensor([0.0185], grad_fn=<DivBackward1>)
# tensor([0.0147], grad_fn=<DivBackward1>)
# tensor([0.0208], grad_fn=<DivBackward1>)
# tensor([0.0294], grad_fn=<DivBackward1>)
# tensor([0.0114], grad_fn=<DivBackward1>)
# tensor([0.0201], grad_fn=<DivBackward1>)
# tensor([0.0027], grad_fn=<DivBackward1>)
# tensor([0.0035], grad_fn=<DivBackward1>)
# tensor([0.0049], grad_fn=<DivBackward1>)
# tensor([0.0231], grad_fn=<DivBackward1>)
# tensor([0.0045], grad_fn=<DivBackward1>)
# tensor([-0.0243], grad_fn=<DivBackward1>)
# Train Epoch: 1 [0/4056 (0%)]	Loss: 0.200148
# tensor([-0.0473], grad_fn=<DivBackward1>)
# tensor([-0.0966], grad_fn=<DivBackward1>)
# tensor([-0.0603], grad_fn=<DivBackward1>)
# tensor([-0.0341], grad_fn=<DivBackward1>)
# tensor([-0.0491], grad_fn=<DivBackward1>)
# tensor([-0.0527], grad_fn=<DivBackward1>)
# tensor([-0.0173], grad_fn=<DivBackward1>)
# tensor([-0.0531], grad_fn=<DivBackward1>)
# tensor([-0.0596], grad_fn=<DivBackward1>)
# tensor([-0.0815], grad_fn=<DivBackward1>)
# tensor([-0.0394], grad_fn=<DivBackward1>)
# tensor([-0.0887], grad_fn=<DivBackward1>)
# tensor([0.0090], grad_fn=<DivBackward1>)
# tensor([-0.0559], grad_fn=<DivBackward1>)
# tensor([-0.0570], grad_fn=<DivBackward1>)
# tensor([-0.0490], grad_fn=<DivBackward1>)
# tensor([-0.0897], grad_fn=<DivBackward1>)
# tensor([-0.0857], grad_fn=<DivBackward1>)
# tensor([-0.0784], grad_fn=<DivBackward1>)
# tensor([-0.0623], grad_fn=<DivBackward1>)
# tensor([-0.0283], grad_fn=<DivBackward1>)
# tensor([-0.0432], grad_fn=<DivBackward1>)
# tensor([-0.0127], grad_fn=<DivBackward1>)
# tensor([-0.0286], grad_fn=<DivBackward1>)
# tensor([-0.0470], grad_fn=<DivBackward1>)
# tensor([-0.1014], grad_fn=<DivBackward1>)
# tensor([-0.0687], grad_fn=<DivBackward1>)
# tensor([-0.0491], grad_fn=<DivBackward1>)
# tensor([-0.0210], grad_fn=<DivBackward1>)
# tensor([-0.0089], grad_fn=<DivBackward1>)
# tensor([-0.0247], grad_fn=<DivBackward1>)
# tensor([-0.0288], grad_fn=<DivBackward1>)
# tensor([-0.0538], grad_fn=<DivBackward1>)
# tensor([-0.0949], grad_fn=<DivBackward1>)
# tensor([-0.0201], grad_fn=<DivBackward1>)
# tensor([-0.0063], grad_fn=<DivBackward1>)
# tensor([-0.0431], grad_fn=<DivBackward1>)
# tensor([-0.0465], grad_fn=<DivBackward1>)
# tensor([-0.0275], grad_fn=<DivBackward1>)
# tensor([-0.0257], grad_fn=<DivBackward1>)
# tensor([-0.0531], grad_fn=<DivBackward1>)
# tensor([-0.0397], grad_fn=<DivBackward1>)
# tensor([-0.0989], grad_fn=<DivBackward1>)
# tensor([0.0015], grad_fn=<DivBackward1>)
# tensor([-0.0308], grad_fn=<DivBackward1>)
# tensor([-0.0810], grad_fn=<DivBackward1>)
# tensor([-0.0537], grad_fn=<DivBackward1>)
# tensor([-0.0503], grad_fn=<DivBackward1>)
# tensor([-0.0683], grad_fn=<DivBackward1>)
# tensor([-0.0009], grad_fn=<DivBackward1>)
# tensor([-0.0655], grad_fn=<DivBackward1>)
# tensor([-0.1172], grad_fn=<DivBackward1>)
# tensor([-0.0053], grad_fn=<DivBackward1>)
# tensor([-0.0573], grad_fn=<DivBackward1>)
# tensor([-0.0881], grad_fn=<DivBackward1>)
# tensor([-0.0521], grad_fn=<DivBackward1>)
# tensor([-0.0423], grad_fn=<DivBackward1>)
# tensor([-0.0567], grad_fn=<DivBackward1>)
# tensor([-0.0083], grad_fn=<DivBackward1>)
# tensor([-0.0762], grad_fn=<DivBackward1>)
# tensor([-0.0281], grad_fn=<DivBackward1>)
# tensor([-0.0697], grad_fn=<DivBackward1>)
# tensor([-0.0481], grad_fn=<DivBackward1>)
# tensor([-0.1045], grad_fn=<DivBackward1>)
# tensor([-0.0828], grad_fn=<DivBackward1>)
# tensor([-0.0121], grad_fn=<DivBackward1>)
# tensor([-0.0576], grad_fn=<DivBackward1>)
# tensor([-0.0289], grad_fn=<DivBackward1>)
# tensor([-0.0419], grad_fn=<DivBackward1>)
# tensor([-0.0857], grad_fn=<DivBackward1>)
# tensor([-0.0485], grad_fn=<DivBackward1>)
# tensor([-0.0508], grad_fn=<DivBackward1>)
# tensor([-0.0600], grad_fn=<DivBackward1>)
# tensor([-0.0528], grad_fn=<DivBackward1>)
# tensor([-0.1009], grad_fn=<DivBackward1>)
# tensor([-0.0582], grad_fn=<DivBackward1>)
# tensor([-0.0169], grad_fn=<DivBackward1>)
# tensor([-0.0613], grad_fn=<DivBackward1>)
# tensor([-0.1061], grad_fn=<DivBackward1>)
# tensor([-0.0521], grad_fn=<DivBackward1>)
# tensor([-0.0008], grad_fn=<DivBackward1>)
# tensor([-0.0476], grad_fn=<DivBackward1>)
# tensor([-0.0529], grad_fn=<DivBackward1>)
# tensor([-0.0700], grad_fn=<DivBackward1>)
# tensor([-0.0317], grad_fn=<DivBackward1>)
# tensor([-0.0523], grad_fn=<DivBackward1>)
# tensor([-0.0921], grad_fn=<DivBackward1>)
# tensor([-0.0386], grad_fn=<DivBackward1>)
# tensor([-0.1224], grad_fn=<DivBackward1>)
# tensor([-0.0504], grad_fn=<DivBackward1>)
# tensor([-0.0711], grad_fn=<DivBackward1>)
# tensor([-0.0746], grad_fn=<DivBackward1>)
# tensor([-0.0776], grad_fn=<DivBackward1>)
# tensor([-0.0196], grad_fn=<DivBackward1>)
# tensor([-0.0260], grad_fn=<DivBackward1>)
# tensor([-0.0782], grad_fn=<DivBackward1>)
# tensor([-0.0416], grad_fn=<DivBackward1>)
# tensor([-0.0715], grad_fn=<DivBackward1>)
# Train Epoch: 1 [98/4056 (2%)]	Loss: 0.192690
# tensor([0.0263], grad_fn=<DivBackward1>)
# tensor([-0.0971], grad_fn=<DivBackward1>)
# tensor([-0.1399], grad_fn=<DivBackward1>)
# tensor([-0.1200], grad_fn=<DivBackward1>)
# tensor([-0.0429], grad_fn=<DivBackward1>)
# tensor([-0.1249], grad_fn=<DivBackward1>)
# tensor([-0.1558], grad_fn=<DivBackward1>)
# tensor([-0.2104], grad_fn=<DivBackward1>)
# tensor([-0.1415], grad_fn=<DivBackward1>)
# tensor([-0.1698], grad_fn=<DivBackward1>)
# tensor([-0.2422], grad_fn=<DivBackward1>)
# tensor([-0.0655], grad_fn=<DivBackward1>)
# tensor([-0.2098], grad_fn=<DivBackward1>)
# tensor([-0.0277], grad_fn=<DivBackward1>)
# tensor([-0.2228], grad_fn=<DivBackward1>)
# tensor([-0.1727], grad_fn=<DivBackward1>)
# tensor([-0.0854], grad_fn=<DivBackward1>)
# tensor([-0.0983], grad_fn=<DivBackward1>)
# tensor([-0.1673], grad_fn=<DivBackward1>)
# tensor([-0.1896], grad_fn=<DivBackward1>)
# tensor([-0.1459], grad_fn=<DivBackward1>)
# tensor([-0.1123], grad_fn=<DivBackward1>)
# tensor([-0.1417], grad_fn=<DivBackward1>)
# tensor([-0.1361], grad_fn=<DivBackward1>)
# tensor([-0.1003], grad_fn=<DivBackward1>)
# tensor([-0.1374], grad_fn=<DivBackward1>)
# tensor([-0.1237], grad_fn=<DivBackward1>)
# tensor([-0.1452], grad_fn=<DivBackward1>)
# tensor([-0.2620], grad_fn=<DivBackward1>)
# tensor([-0.2948], grad_fn=<DivBackward1>)
# tensor([-0.0771], grad_fn=<DivBackward1>)
# tensor([-0.1118], grad_fn=<DivBackward1>)
# tensor([-0.1094], grad_fn=<DivBackward1>)
# tensor([-0.1493], grad_fn=<DivBackward1>)
# tensor([-0.1702], grad_fn=<DivBackward1>)
# tensor([-0.1306], grad_fn=<DivBackward1>)
# tensor([-0.1709], grad_fn=<DivBackward1>)
# tensor([-0.1438], grad_fn=<DivBackward1>)
# tensor([-0.0277], grad_fn=<DivBackward1>)
# tensor([-0.1241], grad_fn=<DivBackward1>)
# tensor([-0.2922], grad_fn=<DivBackward1>)
# tensor([-0.1230], grad_fn=<DivBackward1>)
# tensor([-0.0837], grad_fn=<DivBackward1>)
# tensor([-0.1216], grad_fn=<DivBackward1>)
# tensor([-0.0541], grad_fn=<DivBackward1>)
# tensor([-0.1413], grad_fn=<DivBackward1>)
# tensor([0.0010], grad_fn=<DivBackward1>)
# tensor([-0.2676], grad_fn=<DivBackward1>)
# tensor([-0.0708], grad_fn=<DivBackward1>)
# tensor([-0.1501], grad_fn=<DivBackward1>)
# tensor([-0.0557], grad_fn=<DivBackward1>)
# tensor([-0.1051], grad_fn=<DivBackward1>)
# tensor([-0.0730], grad_fn=<DivBackward1>)
# tensor([-0.2268], grad_fn=<DivBackward1>)
# tensor([-0.2378], grad_fn=<DivBackward1>)
# tensor([-0.0118], grad_fn=<DivBackward1>)
# tensor([-0.0198], grad_fn=<DivBackward1>)
# tensor([-0.0701], grad_fn=<DivBackward1>)
# tensor([-0.0721], grad_fn=<DivBackward1>)
# tensor([-0.1358], grad_fn=<DivBackward1>)
# tensor([-0.2060], grad_fn=<DivBackward1>)
# tensor([-0.0061], grad_fn=<DivBackward1>)
# tensor([-0.1259], grad_fn=<DivBackward1>)
# tensor([-0.1038], grad_fn=<DivBackward1>)
# tensor([-0.2785], grad_fn=<DivBackward1>)
# tensor([-0.1187], grad_fn=<DivBackward1>)
# tensor([-0.1201], grad_fn=<DivBackward1>)
# tensor([-0.1740], grad_fn=<DivBackward1>)
# tensor([-0.1135], grad_fn=<DivBackward1>)
# tensor([-0.0822], grad_fn=<DivBackward1>)
# tensor([-0.1149], grad_fn=<DivBackward1>)
# tensor([-0.0834], grad_fn=<DivBackward1>)
# tensor([-0.1153], grad_fn=<DivBackward1>)
# tensor([-0.2359], grad_fn=<DivBackward1>)
# tensor([-0.1753], grad_fn=<DivBackward1>)
# tensor([-0.0304], grad_fn=<DivBackward1>)
# tensor([-0.1450], grad_fn=<DivBackward1>)
# tensor([-0.2619], grad_fn=<DivBackward1>)
# tensor([-0.0118], grad_fn=<DivBackward1>)
# tensor([-0.0193], grad_fn=<DivBackward1>)
# tensor([-0.1233], grad_fn=<DivBackward1>)
# tensor([-0.0118], grad_fn=<DivBackward1>)
# tensor([-0.0975], grad_fn=<DivBackward1>)
# tensor([-0.0090], grad_fn=<DivBackward1>)
# tensor([-0.0858], grad_fn=<DivBackward1>)
# tensor([-0.0881], grad_fn=<DivBackward1>)
# tensor([-0.1852], grad_fn=<DivBackward1>)
# tensor([-0.0943], grad_fn=<DivBackward1>)
# tensor([-0.0946], grad_fn=<DivBackward1>)
# tensor([-0.2948], grad_fn=<DivBackward1>)
# tensor([-0.1237], grad_fn=<DivBackward1>)
# tensor([-0.1501], grad_fn=<DivBackward1>)
# tensor([-0.1150], grad_fn=<DivBackward1>)
# tensor([-0.0005], grad_fn=<DivBackward1>)
# tensor([-0.1150], grad_fn=<DivBackward1>)
# tensor([-0.1392], grad_fn=<DivBackward1>)
# tensor([-0.1970], grad_fn=<DivBackward1>)
# tensor([-0.0367], grad_fn=<DivBackward1>)
# Train Epoch: 1 [196/4056 (5%)]	Loss: 0.182371
# tensor([-0.2076], grad_fn=<DivBackward1>)
# tensor([-0.1604], grad_fn=<DivBackward1>)
# tensor([-0.1503], grad_fn=<DivBackward1>)
# tensor([-0.0226], grad_fn=<DivBackward1>)
# tensor([-0.1602], grad_fn=<DivBackward1>)
# tensor([-0.2491], grad_fn=<DivBackward1>)
# tensor([-0.1204], grad_fn=<DivBackward1>)
# tensor([-0.2075], grad_fn=<DivBackward1>)
# tensor([-0.1987], grad_fn=<DivBackward1>)
# tensor([-0.1100], grad_fn=<DivBackward1>)
# tensor([-0.0715], grad_fn=<DivBackward1>)
# tensor([-0.1901], grad_fn=<DivBackward1>)
# tensor([-0.2380], grad_fn=<DivBackward1>)
# tensor([-0.0675], grad_fn=<DivBackward1>)
# tensor([-0.3129], grad_fn=<DivBackward1>)
# tensor([-0.1662], grad_fn=<DivBackward1>)
# tensor([-0.1008], grad_fn=<DivBackward1>)
# tensor([-0.1686], grad_fn=<DivBackward1>)
# tensor([-0.0675], grad_fn=<DivBackward1>)
# tensor([-0.3807], grad_fn=<DivBackward1>)
# tensor([-0.3062], grad_fn=<DivBackward1>)
# tensor([-0.3268], grad_fn=<DivBackward1>)
# tensor([-0.1740], grad_fn=<DivBackward1>)
# tensor([-0.2250], grad_fn=<DivBackward1>)
# tensor([-0.2486], grad_fn=<DivBackward1>)
# tensor([-0.1856], grad_fn=<DivBackward1>)
# tensor([-0.1777], grad_fn=<DivBackward1>)
# tensor([-0.2251], grad_fn=<DivBackward1>)
# tensor([-0.1874], grad_fn=<DivBackward1>)
# tensor([-0.3038], grad_fn=<DivBackward1>)
# tensor([-0.0219], grad_fn=<DivBackward1>)
# tensor([-0.0854], grad_fn=<DivBackward1>)
# tensor([-0.2727], grad_fn=<DivBackward1>)
# tensor([-0.1883], grad_fn=<DivBackward1>)
# tensor([-0.3689], grad_fn=<DivBackward1>)
# tensor([-0.1143], grad_fn=<DivBackward1>)
# tensor([-0.0238], grad_fn=<DivBackward1>)
# tensor([-0.1918], grad_fn=<DivBackward1>)
# tensor([-0.2479], grad_fn=<DivBackward1>)
# tensor([-0.1917], grad_fn=<DivBackward1>)
# tensor([-0.1921], grad_fn=<DivBackward1>)
# tensor([-0.1161], grad_fn=<DivBackward1>)
# tensor([-0.4734], grad_fn=<DivBackward1>)
# tensor([-0.1917], grad_fn=<DivBackward1>)
# tensor([-0.1465], grad_fn=<DivBackward1>)
# tensor([-0.1113], grad_fn=<DivBackward1>)
# tensor([-0.3050], grad_fn=<DivBackward1>)
# tensor([-0.1858], grad_fn=<DivBackward1>)
# tensor([-0.2334], grad_fn=<DivBackward1>)
# tensor([-0.2013], grad_fn=<DivBackward1>)
# tensor([-0.1958], grad_fn=<DivBackward1>)
# tensor([-0.2183], grad_fn=<DivBackward1>)
# tensor([-0.0981], grad_fn=<DivBackward1>)
# tensor([-0.3609], grad_fn=<DivBackward1>)
# tensor([-0.1837], grad_fn=<DivBackward1>)
# tensor([-0.1722], grad_fn=<DivBackward1>)
# tensor([-0.1577], grad_fn=<DivBackward1>)
# tensor([-0.3384], grad_fn=<DivBackward1>)
# tensor([-0.4228], grad_fn=<DivBackward1>)
# tensor([-0.1848], grad_fn=<DivBackward1>)
# tensor([-0.0470], grad_fn=<DivBackward1>)
# tensor([-0.1664], grad_fn=<DivBackward1>)
# tensor([-0.1255], grad_fn=<DivBackward1>)
# tensor([-0.1425], grad_fn=<DivBackward1>)
# tensor([-0.3599], grad_fn=<DivBackward1>)
# tensor([-0.2036], grad_fn=<DivBackward1>)
# tensor([-0.4622], grad_fn=<DivBackward1>)
# tensor([-0.4098], grad_fn=<DivBackward1>)
# tensor([-0.1604], grad_fn=<DivBackward1>)
# tensor([-0.0948], grad_fn=<DivBackward1>)
# tensor([-0.3334], grad_fn=<DivBackward1>)
# tensor([-0.3739], grad_fn=<DivBackward1>)
# tensor([-0.1450], grad_fn=<DivBackward1>)
# tensor([-0.3533], grad_fn=<DivBackward1>)
# tensor([-0.2477], grad_fn=<DivBackward1>)
# tensor([-0.1523], grad_fn=<DivBackward1>)
# tensor([-0.3426], grad_fn=<DivBackward1>)
# tensor([-0.1686], grad_fn=<DivBackward1>)
# tensor([-0.2075], grad_fn=<DivBackward1>)
# tensor([-0.1521], grad_fn=<DivBackward1>)
# tensor([-0.2144], grad_fn=<DivBackward1>)
# tensor([-0.1685], grad_fn=<DivBackward1>)
# tensor([-0.2635], grad_fn=<DivBackward1>)
# tensor([-0.1648], grad_fn=<DivBackward1>)
# tensor([-0.0967], grad_fn=<DivBackward1>)
# tensor([-0.0568], grad_fn=<DivBackward1>)
# tensor([-0.2531], grad_fn=<DivBackward1>)
# tensor([-0.1876], grad_fn=<DivBackward1>)
# tensor([-0.2473], grad_fn=<DivBackward1>)
# tensor([-0.2643], grad_fn=<DivBackward1>)
# tensor([-0.1595], grad_fn=<DivBackward1>)
# tensor([-0.2304], grad_fn=<DivBackward1>)
# tensor([-0.2643], grad_fn=<DivBackward1>)
# tensor([-0.1685], grad_fn=<DivBackward1>)
# tensor([-0.4712], grad_fn=<DivBackward1>)
# tensor([-0.1906], grad_fn=<DivBackward1>)
# tensor([-0.2347], grad_fn=<DivBackward1>)
# tensor([-0.2794], grad_fn=<DivBackward1>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-887f29f54759> in <module>()
#       1 for epoch in range(1, epochs + 1):
# ----> 2     train(epoch)
#       3     test(epoch)
#
# <ipython-input-14-88704fb26ab2> in train(epoch)
#     148
#     149         loss = loss_function(reconBatch, data, mu, trainLoader.dataset)
# --> 150         loss.backward()
#     151         trainLoss += loss.item()
#     152         optimizer.step()
#
# ~/Uni/Midi_Parser/.env3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/Uni/Midi_Parser/.env3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
#torch.save(model,'/media/EXTHD/niciData/models/DougMcKenzie14up14down.model')

# %%
print(model.encode1[0].weight.size())

# %%
np.set_printoptions(precision=2, suppress=True, threshold=np.inf)

# %%
###PLAY WHOLE SONG IN BARS
with torch.no_grad():
    
    sampleNp1 = getSlicedPianorollMatrixNp("../DougMcKenzieFiles_noDrums/samples/KingandI.mid")
    for sampleNp in sampleNp1:
        
        if(np.any(sampleNp)):
            #sampleNp = sampleNp[12,:,:]
            #print(sampleNp)
            sampleNp = sampleNp[:,36:-32]
            sample = torch.from_numpy(sampleNp).float()
            noise = torch.bernoulli((torch.rand_like(sample))).to(device)
            sample = sample + noise
            pred, embed = model(sample.reshape(1,1,length,reducedPitch).to(device))
            prediction = pred.squeeze(0).squeeze(0).cpu().numpy()
            
            #print(sampleNp[:,:])
            #print(prediction[:,:])
            #print(np.sum(sampleNp.numpy(), axis=1))
            
            #NORMALIZE PREDICTIONS
            prediction /= np.abs(np.max(prediction))
            
            #CHECK MIDI ACTIVATIONS IN PREDICTION TO INCLUDE RESTS
            prediction[prediction < 0.3] = 0

            

            ###MONOPHONIC OUTPUT MATRIX POLOYPHONIC POSSIBLE WITH ACTIVATION THRESHOLD###
            #score = music21.converter.parse('WikifoniaServer/samples/The-Doors---Don\'t-you-love-her-Madly?.mid')
            #score.show()

            samplePlay = debinarizeMidi(sampleNp, prediction=False)
            samplePlay = addCuttedOctaves(samplePlay)
            prediction = debinarizeMidi(prediction, prediction=True)
            prediction = addCuttedOctaves(prediction)
            #print(np.argmax(samplePlay, axis=1))
            #print('')
            #print(np.argmax(prediction, axis=1))
            print("INPUT")
            pianorollMatrixToTempMidi(samplePlay,show=True,showPlayer=True,autoplay=True)
            #time.sleep(1)
            print("RECONSTRUCTION")
            pianorollMatrixToTempMidi(prediction,show=True,showPlayer=True,autoplay=True)
            print("\n\n")
            

print('')
